# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/3-Practical/FinRL_MultiCrypto_Trading.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Multiple Cryptocurrencies Trading Demo

# %% [markdown]
# ## Installation

# %%
#basic finrl repo
# %cd /
# !git clone https://github.com/AI4Finance-Foundation/FinRL-Meta
# %cd /FinRL-Meta/
# !pip install git+https://github.com/AI4Finance-Foundation/ElegantRL.git
# !pip install wrds
# !pip install swig
#!pip install -q condacolab
#import condacolab
#condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# !pip install yfinance stockstats # python indicators
# !pip install alpaca_trade_api
# !pip install ray[default]
# !pip install lz4 # compression library
# !pip install ray[tune]
# !pip install tensorboardX #help to review tensor flow
# !pip install gputil #getting GPU status
# !pip install trading_calendars
# !pip install wrds #database
# !pip install rqdatac # database
# !pip install sqlalchemy==1.2.19 #python sql toolkit
# !pip install tushare
#install talib
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz 
# !tar xvzf ta-lib-0.4.0-src.tar.gz
import os
os.chdir('ta-lib') 
# !./configure --prefix=/usr
# !make
# !make install
os.chdir('../')
# !pip install TA-Lib
# !pip install baostock
# !pip install quandl
# Out:
# /
# fatal: could not create work tree dir 'FinRL-Meta': Read-only file system
# [Errno 2] No such file or directory: '/FinRL-Meta/'
# /
# Collecting git+https://github.com/AI4Finance-Foundation/ElegantRL.git
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/xm/yvq41t7x57v_01y1jfrj4l6c0000gn/T/pip-req-build-soh2l2st
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/xm/yvq41t7x57v_01y1jfrj4l6c0000gn/T/pip-req-build-soh2l2st
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 4c1893aeeb350e952bdcce916b13e6650a84cd68
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from elegantrl==0.3.6) (1.12.1)
# Requirement already satisfied: numpy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from elegantrl==0.3.6) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from elegantrl==0.3.6) (3.7.0)
# Requirement already satisfied: gym in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from elegantrl==0.3.6) (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gym->elegantrl==0.3.6) (2.0.0)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gym->elegantrl==0.3.6) (2.3.5)
# Requirement already satisfied: pyglet>=1.4.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gym->elegantrl==0.3.6) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (22.0)
# Requirement already satisfied: cycler>=0.10 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib->elegantrl==0.3.6) (4.25.0)
# Requirement already satisfied: typing_extensions in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from torch->elegantrl==0.3.6) (4.4.0)
# Requirement already satisfied: six>=1.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->elegantrl==0.3.6) (1.16.0)
# Requirement already satisfied: wrds in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (3.1.6)
# Requirement already satisfied: pandas in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.5.3)
# Requirement already satisfied: scipy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.10.0)
# Requirement already satisfied: numpy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.23.5)
# Requirement already satisfied: psycopg2-binary in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (2.9.6)
# Requirement already satisfied: sqlalchemy<2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.2.19)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->wrds) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
# Requirement already satisfied: swig in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (4.1.1)
# /bin/bash: apt-get: command not found
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/xm/yvq41t7x57v_01y1jfrj4l6c0000gn/T/pip-req-build-egvjaciz
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/xm/yvq41t7x57v_01y1jfrj4l6c0000gn/T/pip-req-build-egvjaciz
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit b09ebba3e9e27eba6b0880e441e6635679318974
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/xm/yvq41t7x57v_01y1jfrj4l6c0000gn/T/pip-install-nxn60og3/elegantrl_abd3a070b1bf4c25b4055c86ea8f7ae2
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/xm/yvq41t7x57v_01y1jfrj4l6c0000gn/T/pip-install-nxn60og3/elegantrl_abd3a070b1bf4c25b4055c86ea8f7ae2
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 4c1893aeeb350e952bdcce916b13e6650a84cd68
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (0.9.2)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (0.5.2)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (1.2.1)
# Requirement already satisfied: exchange-calendars<5,>=4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (4.2.8)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (0.2.18)
# Requirement already satisfied: jqdatasdk<2,>=1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (1.8.11)
# Requirement already satisfied: ccxt<4,>=3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (3.1.13)
# Requirement already satisfied: ray[default,tune]<3,>=2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (2.4.0)
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (2.0.0)
# Requirement already satisfied: wrds<4,>=3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (3.1.6)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (1.5.5)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (3.0.0)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (0.57.0)
# Requirement already satisfied: msgpack==1.0.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.14)
# Requirement already satisfied: deprecation==2.1.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: pandas>=0.18.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.5.3)
# Requirement already satisfied: aiohttp==3.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.8.1)
# Requirement already satisfied: requests<3,>2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.28.1)
# Requirement already satisfied: PyYAML==6.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0)
# Requirement already satisfied: websockets<11,>=9.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.23.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.2)
# Requirement already satisfied: packaging in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (22.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (2022.12.7)
# Requirement already satisfied: setuptools>=60.9.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (65.6.3)
# Requirement already satisfied: aiodns>=1.1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: cryptography>=2.6.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (39.0.1)
# Requirement already satisfied: pytz in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2022.7)
# Requirement already satisfied: toolz in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Requirement already satisfied: korean-lunar-calendar in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: python-dateutil in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: pyluach in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: thriftpy2>=0.3.9 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.16)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.2.19)
# Requirement already satisfied: six in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: pymysql>=0.7.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: empyrical>=0.5.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: seaborn>=0.7.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.2)
# Requirement already satisfied: ipython>=3.2.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.10.0)
# Requirement already satisfied: scipy>=0.14.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.10.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.0)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: jsonschema in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.17.3)
# Requirement already satisfied: click>=7.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.0.4)
# Requirement already satisfied: filelock in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.9.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.20.3)
# Requirement already satisfied: grpcio<=1.49.1,>=1.42.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.49.1)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.21.0)
# Requirement already satisfied: pydantic in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.10.8)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.14)
# Requirement already satisfied: colorful in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: aiohttp-cors in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: opencensus in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.2)
# Requirement already satisfied: gpustat>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.1)
# Requirement already satisfied: smart-open in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (5.2.1)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.14.1)
# Requirement already satisfied: tabulate in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.8.10)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6)
# Requirement already satisfied: joblib>=1.1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: cloudpickle in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: gymnasium==0.28.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.28.1)
# Requirement already satisfied: torch>=1.11 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.12.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: rich in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.3.5)
# Requirement already satisfied: shimmy[atari]~=0.2.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.2.1)
# Requirement already satisfied: pillow in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.4.0)
# Requirement already satisfied: psutil in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.13.0)
# Requirement already satisfied: opencv-python in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.7.0.72)
# Requirement already satisfied: tqdm in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.64.1)
# Requirement already satisfied: pygame in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.4.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: psycopg2-binary in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.11.1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.1)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.8)
# Requirement already satisfied: gym in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.21.0)
# Requirement already satisfied: pycares>=4.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.3.0)
# Requirement already satisfied: AutoROM.accept-rom-license in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.15.1)
# Requirement already satisfied: scs>=1.1.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.3)
# Requirement already satisfied: osqp>=0.4.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.3)
# Requirement already satisfied: ecos>=2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: pandas-datareader>=0.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (11.525.112)
# Requirement already satisfied: blessed>=1.17.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.20.0)
# Requirement already satisfied: webencodings in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: pickleshare in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: stack-data in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.18.1)
# Requirement already satisfied: decorator in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: appnope in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.15.1)
# Requirement already satisfied: backcall in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.36)
# Requirement already satisfied: matplotlib-inline in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Requirement already satisfied: ale-py~=0.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.19.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.1)
# Requirement already satisfied: ply<4.0,>=3.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: platformdirs<4,>=2.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.6)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.3.5)
# Requirement already satisfied: pyglet>=1.4.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.0.7)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.18.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.11.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: importlib-resources in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.12.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.5)
# Requirement already satisfied: pycparser in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.1)
# Requirement already satisfied: pure-eval in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Requirement already satisfied: executing in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: asttokens in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.0.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)
# Requirement already satisfied: yfinance in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (0.2.18)
# Requirement already satisfied: stockstats in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (39.0.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (2022.7)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pandas>=1.3.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: requests>=2.26 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: lxml>=4.9.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: pycparser in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: alpaca_trade_api in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (1.26.14)
# Requirement already satisfied: PyYAML==6.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (2.1.0)
# Requirement already satisfied: aiohttp==3.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (3.8.1)
# Requirement already satisfied: websockets<11,>=9.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (10.4)
# Requirement already satisfied: requests<3,>2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (2.28.1)
# Requirement already satisfied: pandas>=0.18.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (1.5.3)
# Requirement already satisfied: numpy>=1.11.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (1.23.5)
# Requirement already satisfied: msgpack==1.0.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (1.0.3)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from alpaca_trade_api) (0.57.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.9.2)
# Requirement already satisfied: packaging in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca_trade_api) (22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2022.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests<3,>2->alpaca_trade_api) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests<3,>2->alpaca_trade_api) (3.4)
# Requirement already satisfied: six in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from websocket-client<2,>=0.56.0->alpaca_trade_api) (1.16.0)
# Requirement already satisfied: ray[default] in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.0.3)
# Requirement already satisfied: click>=7.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (8.0.4)
# Requirement already satisfied: packaging in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (22.0)
# Requirement already satisfied: aiosignal in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.3.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (3.20.3)
# Requirement already satisfied: frozenlist in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.3.3)
# Requirement already satisfied: grpcio<=1.49.1,>=1.42.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.49.1)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (20.21.0)
# Requirement already satisfied: jsonschema in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (4.17.3)
# Requirement already satisfied: numpy>=1.19.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.23.5)
# Requirement already satisfied: pyyaml in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (6.0)
# Requirement already satisfied: filelock in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (3.9.0)
# Requirement already satisfied: requests in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (2.28.1)
# Requirement already satisfied: attrs in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (22.1.0)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (0.3.14)
# Requirement already satisfied: aiohttp-cors in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (0.7.0)
# Requirement already satisfied: smart-open in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (5.2.1)
# Requirement already satisfied: gpustat>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.1)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (0.14.1)
# Requirement already satisfied: colorful in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (0.5.5)
# Requirement already satisfied: aiohttp>=3.7 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (3.8.1)
# Requirement already satisfied: pydantic in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (1.10.8)
# Requirement already satisfied: opencensus in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[default]) (0.11.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]) (2.0.4)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default]) (11.525.112)
# Requirement already satisfied: psutil>=5.6.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default]) (5.9.0)
# Requirement already satisfied: blessed>=1.17.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default]) (1.20.0)
# Requirement already satisfied: six>=1.5.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from grpcio<=1.49.1,>=1.42.0->ray[default]) (1.16.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]) (0.3.6)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jsonschema->ray[default]) (0.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from opencensus->ray[default]) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from opencensus->ray[default]) (2.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pydantic->ray[default]) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[default]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[default]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[default]) (1.26.14)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]) (0.2.5)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (2.19.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.59.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.4.8)
# Requirement already satisfied: lz4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (3.1.3)
# Requirement already satisfied: ray[tune] in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: click>=7.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (8.0.4)
# Requirement already satisfied: numpy>=1.19.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (1.23.5)
# Requirement already satisfied: jsonschema in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (4.17.3)
# Requirement already satisfied: filelock in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (3.9.0)
# Requirement already satisfied: attrs in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (22.1.0)
# Requirement already satisfied: frozenlist in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (1.3.3)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (20.21.0)
# Requirement already satisfied: grpcio<=1.49.1,>=1.42.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (1.49.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied: packaging in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (22.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (3.20.3)
# Requirement already satisfied: requests in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (2.28.1)
# Requirement already satisfied: pyyaml in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (6.0)
# Requirement already satisfied: aiosignal in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (1.3.1)
# Requirement already satisfied: tabulate in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (0.8.10)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (2.6)
# Requirement already satisfied: pandas in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from ray[tune]) (1.5.3)
# Requirement already satisfied: six>=1.5.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from grpcio<=1.49.1,>=1.42.0->ray[tune]) (1.16.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[tune]) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from virtualenv<20.21.1,>=20.0.24->ray[tune]) (0.3.6)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from jsonschema->ray[tune]) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->ray[tune]) (2022.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[tune]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[tune]) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[tune]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->ray[tune]) (2022.12.7)
# Requirement already satisfied: tensorboardX in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (2.6)
# Requirement already satisfied: packaging in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboardX) (22.0)
# Requirement already satisfied: numpy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: gputil in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: trading_calendars in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: toolz in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from trading_calendars) (0.12.0)
# Requirement already satisfied: six in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from trading_calendars) (1.16.0)
# Requirement already satisfied: pandas in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from trading_calendars) (1.5.3)
# Requirement already satisfied: pytz in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from trading_calendars) (2022.7)
# Requirement already satisfied: numpy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from trading_calendars) (1.23.5)
# Requirement already satisfied: python-dateutil in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from trading_calendars) (2.8.2)
# Requirement already satisfied: wrds in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (3.1.6)
# Requirement already satisfied: psycopg2-binary in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (2.9.6)
# Requirement already satisfied: scipy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.10.0)
# Requirement already satisfied: numpy in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.23.5)
# Requirement already satisfied: sqlalchemy<2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.2.19)
# Requirement already satisfied: pandas in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from wrds) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->wrds) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
# Requirement already satisfied: rqdatac in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (2.11.4.1)
# Requirement already satisfied: brotli in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (1.0.9)
# Requirement already satisfied: zstandard in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (0.19.0)
# Requirement already satisfied: pymysql in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (1.0.3)
# Requirement already satisfied: python-dateutil in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (2.8.2)
# Requirement already satisfied: six in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (1.16.0)
# Collecting SQLAlchemy>=1.4
#   Downloading SQLAlchemy-2.0.20-cp310-cp310-macosx_10_9_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.2 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: orjson in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (3.9.3)
# Requirement already satisfied: python-rapidjson in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (1.10)
# Requirement already satisfied: msgpack>=0.5.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (1.0.3)
# Requirement already satisfied: pandas in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from rqdatac) (1.5.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from SQLAlchemy>=1.4->rqdatac) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from SQLAlchemy>=1.4->rqdatac) (4.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->rqdatac) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->rqdatac) (1.23.5)
# Installing collected packages: SQLAlchemy
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 1.2.19
#     Uninstalling SQLAlchemy-1.2.19:
#       Successfully uninstalled SQLAlchemy-1.2.19
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wrds 3.1.6 requires sqlalchemy<2, but you have sqlalchemy 2.0.20 which is incompatible.
# Successfully installed SQLAlchemy-2.0.20
# Collecting sqlalchemy==1.2.19
#   Using cached SQLAlchemy-1.2.19-cp310-cp310-macosx_10_9_x86_64.whl
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.20
#     Uninstalling SQLAlchemy-2.0.20:
#       Successfully uninstalled SQLAlchemy-2.0.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rqdatac 2.11.4.1 requires SQLAlchemy>=1.4, but you have sqlalchemy 1.2.19 which is incompatible.
# Successfully installed sqlalchemy-1.2.19
# Requirement already satisfied: tushare in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (1.2.89)
# Requirement already satisfied: websocket-client==0.57.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tushare) (0.57.0)
# Requirement already satisfied: bs4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tushare) (0.0.1)
# Requirement already satisfied: simplejson in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tushare) (3.19.1)
# Requirement already satisfied: requests in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tushare) (2.28.1)
# Requirement already satisfied: pandas in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tushare) (1.5.3)
# Requirement already satisfied: lxml in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from tushare) (4.9.1)
# Requirement already satisfied: six in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from websocket-client==0.57.0->tushare) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from bs4->tushare) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->tushare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->tushare) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from pandas->tushare) (1.23.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->tushare) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->tushare) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->tushare) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from requests->tushare) (2022.12.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/chelseananda/anaconda3/lib/python3.10/site-packages (from beautifulsoup4->bs4->tushare) (2.3.2.post1)
# /bin/bash: wget: command not found
# tar: Error opening archive: Failed to open 'ta-lib-0.4.0-src.tar.gz'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 29
#      27 get_ipython().system('tar xvzf ta-lib-0.4.0-src.tar.gz')
#      28 import os
# ---> 29 os.chdir('ta-lib')
#      30 get_ipython().system('./configure --prefix=/usr')
#      31 get_ipython().system('make')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ta-lib'

# %% [markdown]
# ## Import Related Packages

# %%
# %cd /FinRL-Meta/
from meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
# Out:
# /FinRL-Meta

# %% [markdown]
# ## Functions for Training and Testing

# %%
from agents.elegantrl_models import DRLAgent as DRLAgent_erl
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from meta.data_processor import DataProcessor

def train(start_date, end_date, ticker_list, data_source, time_interval, 
          technical_indicator_list, drl_lib, env, model_name, if_vix=True,
          **kwargs):
    
    #process data using unified data processor
    DP = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
    price_array, tech_array, turbulence_array = DP.run(ticker_list,
                                                        technical_indicator_list, 
                                                        if_vix, cache=True)

    data_config = {'price_array': price_array,
                   'tech_array': tech_array,
                   'turbulence_array': turbulence_array}

    #build environment using processed data
    env_instance = env(config=data_config)

    #read parameters and load agents
    current_working_dir = kwargs.get('current_working_dir','./'+str(model_name))

    if drl_lib == 'elegantrl':
        break_step = kwargs.get('break_step', 1e6)
        erl_params = kwargs.get('erl_params')

        agent = DRLAgent_erl(env = env,
                             price_array = price_array,
                             tech_array=tech_array,
                             turbulence_array=turbulence_array)

        model = agent.get_model(model_name, model_kwargs = erl_params)

        trained_model = agent.train_model(model=model, 
                                          cwd=current_working_dir,
                                          total_timesteps=break_step)
        
      
    elif drl_lib == 'rllib':
        total_episodes = kwargs.get('total_episodes', 100)
        rllib_params = kwargs.get('rllib_params')

        agent_rllib = DRLAgent_rllib(env = env,
                       price_array=price_array,
                       tech_array=tech_array,
                       turbulence_array=turbulence_array)

        model,model_config = agent_rllib.get_model(model_name)

        model_config['lr'] = rllib_params['lr']
        model_config['train_batch_size'] = rllib_params['train_batch_size']
        model_config['gamma'] = rllib_params['gamma']

        trained_model = agent_rllib.train_model(model=model, 
                                          model_name=model_name,
                                          model_config=model_config,
                                          total_episodes=total_episodes)
        trained_model.save(current_working_dir)
        
            
    elif drl_lib == 'stable_baselines3':
        total_timesteps = kwargs.get('total_timesteps', 1e6)
        agent_params = kwargs.get('agent_params')

        agent = DRLAgent_sb3(env = env_instance)

        model = agent.get_model(model_name, model_kwargs = agent_params)
        trained_model = agent.train_model(model=model, 
                                tb_log_name=model_name,
                                total_timesteps=total_timesteps)
        print('Training finished!')
        trained_model.save(current_working_dir)
        print('Trained model saved in ' + str(current_working_dir))
    else:
        raise ValueError('DRL library input is NOT supported. Please check.')

# %%
# import DRL agents
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

# import data processor
from meta.data_processor import DataProcessor

def test(start_date, end_date, ticker_list, data_source, time_interval,
            technical_indicator_list, drl_lib, env, model_name, if_vix=True,
            **kwargs):
  
    #process data using unified data processor
    DP = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
    price_array, tech_array, turbulence_array = DP.run(ticker_list,
                                                        technical_indicator_list, 
                                                        if_vix, cache=True)
    
    
    np.save('./price_array.npy', price_array)
    data_config = {'price_array':price_array,
                   'tech_array':tech_array,
                   'turbulence_array':turbulence_array}
    #build environment using processed data
    env_instance = env(config=data_config)

    env_config = {
        "price_array": price_array,
        "tech_array": tech_array,
        "turbulence_array": turbulence_array,
        "if_train": False,
    }
    env_instance = env(config=env_config)

    # load elegantrl needs state dim, action dim and net dim
    net_dimension = kwargs.get("net_dimension", 2 ** 7)
    current_working_dir = kwargs.get("current_working_dir", "./" + str(model_name))
    print("price_array: ", len(price_array))

    if drl_lib == "elegantrl":
        episode_total_assets = DRLAgent_erl.DRL_prediction(
            model_name=model_name,
            cwd=current_working_dir,
            net_dimension=net_dimension,
            environment=env_instance,
        )

        return episode_total_assets

    elif drl_lib == "rllib":
        # load agent
        episode_total_assets = DRLAgent_rllib.DRL_prediction(
            model_name=model_name,
            env=env,
            price_array=price_array,
            tech_array=tech_array,
            turbulence_array=turbulence_array,
            agent_path=current_working_dir,
        )

        return episode_total_assets

    elif drl_lib == "stable_baselines3":
        episode_total_assets = DRLAgent_sb3.DRL_prediction_load_from_file(
            model_name=model_name, environment=env_instance, cwd=current_working_dir
        )

        return episode_total_assets
    else:
        raise ValueError("DRL library input is NOT supported. Please check.")

# %% [markdown]
# ## Multiple Cryptocurrencies Trading Env

# %%
import numpy as np
import math

class CryptoEnv:  # custom env
    def __init__(self, config, lookback=1, initial_capital=1e6, 
                 buy_cost_pct=1e-3, sell_cost_pct=1e-3, gamma=0.99):
        self.lookback = lookback
        self.initial_total_asset = initial_capital
        self.initial_cash = initial_capital
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.max_stock = 1
        self.gamma = gamma
        self.price_array = config['price_array']
        self.tech_array = config['tech_array']
        self._generate_action_normalizer()
        self.crypto_num = self.price_array.shape[1]
        self.max_step = self.price_array.shape[0] - lookback - 1
        
        # reset
        self.time = lookback-1
        self.cash = self.initial_cash
        self.current_price = self.price_array[self.time]
        self.current_tech = self.tech_array[self.time]
        self.stocks = np.zeros(self.crypto_num, dtype=np.float32)

        self.total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        self.episode_return = 0.0  
        self.gamma_return = 0.0
        

        '''env information'''
        self.env_name = 'MulticryptoEnv'
        self.state_dim = 1 + (self.price_array.shape[1] + self.tech_array.shape[1])*lookback
        self.action_dim = self.price_array.shape[1]
        self.if_discrete = False
        self.target_return = 10


    def reset(self) -> np.ndarray:
        self.time = self.lookback-1
        self.current_price = self.price_array[self.time]
        self.current_tech = self.tech_array[self.time]
        self.cash = self.initial_cash  # reset()
        self.stocks = np.zeros(self.crypto_num, dtype=np.float32)
        self.total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        
        state = self.get_state()
        return state

    def step(self, actions) -> (np.ndarray, float, bool, None):
        self.time += 1
        
        price = self.price_array[self.time]
        for i in range(self.action_dim):
            norm_vector_i = self.action_norm_vector[i]
            actions[i] = actions[i] * norm_vector_i
            
        for index in np.where(actions < 0)[0]:  # sell_index:
            if price[index] > 0:  # Sell only if current asset is > 0
                sell_num_shares = min(self.stocks[index], -actions[index])
                self.stocks[index] -= sell_num_shares
                self.cash += price[index] * sell_num_shares * (1 - self.sell_cost_pct)
                
        for index in np.where(actions > 0)[0]:  # buy_index:
            if price[index] > 0:  # Buy only if the price is > 0 (no missing data in this particular date)
                buy_num_shares = min(self.cash // price[index], actions[index])
                self.stocks[index] += buy_num_shares
                self.cash -= price[index] * buy_num_shares * (1 + self.buy_cost_pct)

        """update time"""
        done = self.time == self.max_step
        state = self.get_state()
        next_total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        reward = (next_total_asset - self.total_asset) * 2 ** -16  
        self.total_asset = next_total_asset
        self.gamma_return = self.gamma_return * self.gamma + reward 
        self.cumu_return = self.total_asset / self.initial_cash
        if done:
            reward = self.gamma_return
            self.episode_return = self.total_asset / self.initial_cash
        return state, reward, done, None

    def get_state(self):
        state =  np.hstack((self.cash * 2 ** -18, self.stocks * 2 ** -3))
        for i in range(self.lookback):
            tech_i = self.tech_array[self.time-i]
            normalized_tech_i = tech_i * 2 ** -15
            state = np.hstack((state, normalized_tech_i)).astype(np.float32)
        return state
    
    def close(self):
        pass

    def _generate_action_normalizer(self):
        action_norm_vector = []
        price_0 = self.price_array[0]
        for price in price_0:
            x = math.floor(math.log(price, 10)) #the order of magnitude 
            action_norm_vector.append(1/((10)**x)) 
            
        action_norm_vector = np.asarray(action_norm_vector) * 10000
        self.action_norm_vector = np.asarray(action_norm_vector)

# %% [markdown]
# ## Set Parameters

# %%
TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
env = CryptoEnv
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2021-09-02'

TEST_START_DATE = '2021-09-21'
TEST_END_DATE = '2021-09-30'

INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

# %% [markdown]
# ## Training

# %%
train(start_date=TRAIN_START_DATE, 
      end_date=TRAIN_END_DATE,
      ticker_list=TICKER_LIST, 
      data_source='binance',
      time_interval='5m', 
      technical_indicator_list=INDICATORS,
      drl_lib='elegantrl', 
      env=env, 
      model_name='ppo', 
      current_working_dir='./test_ppo',
      erl_params=ERL_PARAMS,
      break_step=5e4,
      if_vix=False
      )
# Out:
# binance successfully connected
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# Successfully transformed into array
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c3f95f8e0ccd> in <module>()
#      11       erl_params=ERL_PARAMS,
#      12       break_step=5e4,
# ---> 13       if_vix=False
#      14       )
#
# <ipython-input-4-c2f4f1f1ce9a> in train(start_date, end_date, ticker_list, data_source, time_interval, technical_indicator_list, drl_lib, env, model_name, if_vix, **kwargs)
#      33                              turbulence_array=turbulence_array)
#      34
# ---> 35         model = agent.get_model(model_name, model_kwargs = erl_params)
#      36
#      37         trained_model = agent.train_model(model=model,
#
# /FinRL-Meta/agents/elegantrl_models.py in get_model(self, model_name, model_kwargs)
#      56         if model_name not in MODELS:
#      57             raise NotImplementedError("NotImplementedError")
# ---> 58         model = Arguments(agent=agent, env=env)
#      59         model.if_off_policy = model_name in OFF_POLICY_MODELS
#      60         if model_kwargs is not None:
#
# TypeError: __init__() got an unexpected keyword argument 'agent'

# %% [markdown]
# ## Testing

# %%
account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER_LIST, 
                        data_source = 'binance',
                        time_interval= '5m', 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='ppo', 
                        current_working_dir='./test_ppo', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
# %matplotlib inline
#calculate agent returns
account_value_erl = np.array(account_value_erl)
agent_returns = account_value_erl/account_value_erl[0]
#calculate buy-and-hold btc returns
price_array = np.load('./price_array.npy')
btc_prices = price_array[:,0]
buy_hold_btc_returns = btc_prices/btc_prices[0]
#calculate equal weight portfolio returns
price_array = np.load('./price_array.npy')
initial_prices = price_array[0,:]
equal_weight = np.array([1e5/initial_prices[i] for i in range(len(TICKER_LIST))])
equal_weight_values = []
for i in range(0, price_array.shape[0]):
    equal_weight_values.append(np.sum(equal_weight * price_array[i]))
equal_weight_values = np.array(equal_weight_values)
equal_returns = equal_weight_values/equal_weight_values[0]
#plot 
plt.figure(dpi=200)
plt.grid()
plt.grid(which='minor', axis='y')
plt.title('Cryptocurrency Trading ', fontsize=20)
plt.plot(agent_returns, label='ElegantRL Agent', color = 'red')
plt.plot(buy_hold_btc_returns, label='Buy-and-Hold BTC', color='blue')
plt.plot(equal_returns, label='Equal Weight Portfolio', color='green')
plt.ylabel('Return', fontsize=16)
plt.xlabel('Times (5min)', fontsize=16)
plt.xticks(size=14)
plt.yticks(size=14)
'''ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(210))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(21))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.005))
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=2))
ax.xaxis.set_major_formatter(ticker.FixedFormatter([]))'''
plt.legend(fontsize=10.5)
