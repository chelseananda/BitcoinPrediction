# %%
# Commented out IPython magic to ensure Python compatibility.
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xvzf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# %cd /content  # Change this to the appropriate directory if needed
# !pip install TA-Lib
# Out:
# --2023-11-17 19:00:46--  http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# Resolving prdownloads.sourceforge.net (prdownloads.sourceforge.net)... 204.68.111.105
# Connecting to prdownloads.sourceforge.net (prdownloads.sourceforge.net)|204.68.111.105|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2023-11-17 19:00:46--  http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Reusing existing connection to prdownloads.sourceforge.net:80.
# HTTP request sent, awaiting response... 302 Found
# Location: http://phoenixnap.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2023-11-17 19:00:47--  http://phoenixnap.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving phoenixnap.dl.sourceforge.net (phoenixnap.dl.sourceforge.net)... 184.164.141.26
# Connecting to phoenixnap.dl.sourceforge.net (phoenixnap.dl.sourceforge.net)|184.164.141.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330299 (1.3M) [application/x-gzip]
# Saving to: ‘ta-lib-0.4.0-src.tar.gz.1’
#
# ta-lib-0.4.0-src.ta 100%[===================>]   1.27M  2.51MB/s    in 0.5s
#
# 2023-11-17 19:00:47 (2.51 MB/s) - ‘ta-lib-0.4.0-src.tar.gz.1’ saved [1330299/1330299]
#
# ta-lib/
# ta-lib/config.sub
# ta-lib/aclocal.m4
# ta-lib/CHANGELOG.TXT
# ta-lib/include/
# ta-lib/include/ta_abstract.h
# ta-lib/include/ta_func.h
# ta-lib/include/ta_common.h
# ta-lib/include/ta_config.h.in
# ta-lib/include/Makefile.am
# ta-lib/include/ta_libc.h
# ta-lib/include/ta_defs.h
# ta-lib/missing
# ta-lib/ta-lib.spec.in
# ta-lib/config.guess
# ta-lib/Makefile.in
# ta-lib/ta-lib.dpkg.in
# ta-lib/Makefile.am
# ta-lib/autogen.sh
# ta-lib/install-sh
# ta-lib/configure
# ta-lib/depcomp
# ta-lib/HISTORY.TXT
# ta-lib/configure.in
# ta-lib/autom4te.cache/
# ta-lib/autom4te.cache/output.0
# ta-lib/autom4te.cache/requests
# ta-lib/autom4te.cache/output.1
# ta-lib/autom4te.cache/traces.0
# ta-lib/autom4te.cache/traces.1
# ta-lib/ltmain.sh
# ta-lib/ta-lib-config.in
# ta-lib/src/
# ta-lib/src/ta_func/
# ta-lib/src/ta_func/ta_MACDFIX.c
# ta-lib/src/ta_func/ta_CDLPIERCING.c
# ta-lib/src/ta_func/ta_DIV.c
# ta-lib/src/ta_func/ta_ROCR100.c
# ta-lib/src/ta_func/ta_ADXR.c
# ta-lib/src/ta_func/ta_MAVP.c
# ta-lib/src/ta_func/ta_CDLCLOSINGMARUBOZU.c
# ta-lib/src/ta_func/ta_COSH.c
# ta-lib/src/ta_func/ta_EXP.c
# ta-lib/src/ta_func/ta_MINMAXINDEX.c
# ta-lib/src/ta_func/ta_SQRT.c
# ta-lib/src/ta_func/ta_FLOOR.c
# ta-lib/src/ta_func/ta_CDLCONCEALBABYSWALL.c
# ta-lib/src/ta_func/ta_NATR.c
# ta-lib/src/ta_func/ta_CDLHARAMICROSS.c
# ta-lib/src/ta_func/ta_MINUS_DM.c
# ta-lib/src/ta_func/ta_LOG10.c
# ta-lib/src/ta_func/ta_LINEARREG_ANGLE.c
# ta-lib/src/ta_func/ta_RSI.c
# ta-lib/src/ta_func/ta_CDLABANDONEDBABY.c
# ta-lib/src/ta_func/ta_SAR.c
# ta-lib/src/ta_func/ta_CDLBREAKAWAY.c
# ta-lib/src/ta_func/ta_CDLDRAGONFLYDOJI.c
# ta-lib/src/ta_func/ta_CDLHIGHWAVE.c
# ta-lib/src/ta_func/ta_CDLKICKING.c
# ta-lib/src/ta_func/ta_CDLDOJISTAR.c
# ta-lib/src/ta_func/ta_VAR.c
# ta-lib/src/ta_func/ta_CDLMATCHINGLOW.c
# ta-lib/src/ta_func/ta_CDLGAPSIDESIDEWHITE.c
# ta-lib/src/ta_func/ta_CDLMARUBOZU.c
# ta-lib/src/ta_func/ta_AROONOSC.c
# ta-lib/src/ta_func/ta_WCLPRICE.c
# ta-lib/src/ta_func/ta_CDLEVENINGDOJISTAR.c
# ta-lib/src/ta_func/ta_CDL3INSIDE.c
# ta-lib/src/ta_func/ta_OBV.c
# ta-lib/src/ta_func/ta_AROON.c
# ta-lib/src/ta_func/ta_CDLBELTHOLD.c
# ta-lib/src/ta_func/ta_CDLSPINNINGTOP.c
# ta-lib/src/ta_func/ta_AD.c
# ta-lib/src/ta_func/ta_MAX.c
# ta-lib/src/ta_func/ta_CDLENGULFING.c
# ta-lib/src/ta_func/ta_MINMAX.c
# ta-lib/src/ta_func/ta_CDLINNECK.c
# ta-lib/src/ta_func/ta_STDDEV.c
# ta-lib/src/ta_func/ta_NVI.c
# ta-lib/src/ta_func/ta_CDLHAMMER.c
# ta-lib/src/ta_func/ta_ASIN.c
# ta-lib/src/ta_func/ta_SUM.c
# ta-lib/src/ta_func/ta_STOCH.c
# ta-lib/src/ta_func/ta_CDLLONGLEGGEDDOJI.c
# ta-lib/src/ta_func/ta_MEDPRICE.c
# ta-lib/src/ta_func/ta_CDL3STARSINSOUTH.c
# ta-lib/src/ta_func/ta_HT_TRENDMODE.c
# ta-lib/src/ta_func/ta_BBANDS.c
# ta-lib/src/ta_func/ta_CDLMORNINGSTAR.c
# ta-lib/src/ta_func/ta_HT_DCPHASE.c
# ta-lib/src/ta_func/ta_CDLLONGLINE.c
# ta-lib/src/ta_func/ta_TAN.c
# ta-lib/src/ta_func/ta_SMA.c
# ta-lib/src/ta_func/ta_DX.c
# ta-lib/src/ta_func/ta_MIDPOINT.c
# ta-lib/src/ta_func/ta_CDL2CROWS.c
# ta-lib/src/ta_func/ta_CORREL.c
# ta-lib/src/ta_func/ta_CDL3BLACKCROWS.c
# ta-lib/src/ta_func/ta_ADD.c
# ta-lib/src/ta_func/Makefile.in
# ta-lib/src/ta_func/ta_CDLTHRUSTING.c
# ta-lib/src/ta_func/ta_SUB.c
# ta-lib/src/ta_func/ta_CDLSTALLEDPATTERN.c
# ta-lib/src/ta_func/ta_CDLTRISTAR.c
# ta-lib/src/ta_func/ta_MA.c
# ta-lib/src/ta_func/ta_HT_SINE.c
# ta-lib/src/ta_func/ta_ACOS.c
# ta-lib/src/ta_func/ta_CDLSTICKSANDWICH.c
# ta-lib/src/ta_func/ta_SINH.c
# ta-lib/src/ta_func/ta_utility.h
# ta-lib/src/ta_func/ta_CDLSHORTLINE.c
# ta-lib/src/ta_func/ta_ATAN.c
# ta-lib/src/ta_func/ta_CDLADVANCEBLOCK.c
# ta-lib/src/ta_func/ta_CDLKICKINGBYLENGTH.c
# ta-lib/src/ta_func/ta_CDLSHOOTINGSTAR.c
# ta-lib/src/ta_func/ta_ROCR.c
# ta-lib/src/ta_func/ta_WMA.c
# ta-lib/src/ta_func/ta_CDLDARKCLOUDCOVER.c
# ta-lib/src/ta_func/ta_CDLXSIDEGAP3METHODS.c
# ta-lib/src/ta_func/ta_TYPPRICE.c
# ta-lib/src/ta_func/ta_CDL3WHITESOLDIERS.c
# ta-lib/src/ta_func/Makefile.am
# ta-lib/src/ta_func/ta_MACDEXT.c
# ta-lib/src/ta_func/ta_ADX.c
# ta-lib/src/ta_func/ta_PLUS_DM.c
# ta-lib/src/ta_func/ta_CDLUPSIDEGAP2CROWS.c
# ta-lib/src/ta_func/ta_LN.c
# ta-lib/src/ta_func/ta_DEMA.c
# ta-lib/src/ta_func/ta_CDL3OUTSIDE.c
# ta-lib/src/ta_func/ta_CDLTASUKIGAP.c
# ta-lib/src/ta_func/ta_MAMA.c
# ta-lib/src/ta_func/ta_CDLMORNINGDOJISTAR.c
# ta-lib/src/ta_func/ta_PLUS_DI.c
# ta-lib/src/ta_func/ta_MININDEX.c
# ta-lib/src/ta_func/ta_COS.c
# ta-lib/src/ta_func/ta_HT_TRENDLINE.c
# ta-lib/src/ta_func/ta_MIDPRICE.c
# ta-lib/src/ta_func/ta_CEIL.c
# ta-lib/src/ta_func/ta_TRIMA.c
# ta-lib/src/ta_func/ta_CDLSEPARATINGLINES.c
# ta-lib/src/ta_func/ta_ROCP.c
# ta-lib/src/ta_func/ta_CDLHOMINGPIGEON.c
# ta-lib/src/ta_func/ta_CDLHANGINGMAN.c
# ta-lib/src/ta_func/ta_AVGPRICE.c
# ta-lib/src/ta_func/ta_APO.c
# ta-lib/src/ta_func/ta_CDLRISEFALL3METHODS.c
# ta-lib/src/ta_func/ta_TRANGE.c
# ta-lib/src/ta_func/ta_TSF.c
# ta-lib/src/ta_func/ta_LINEARREG.c
# ta-lib/src/ta_func/ta_PVI.c
# ta-lib/src/ta_func/ta_CDLHIKKAKEMOD.c
# ta-lib/src/ta_func/ta_MFI.c
# ta-lib/src/ta_func/ta_CDLHARAMI.c
# ta-lib/src/ta_func/ta_MACD.c
# ta-lib/src/ta_func/ta_BETA.c
# ta-lib/src/ta_func/ta_CDLINVERTEDHAMMER.c
# ta-lib/src/ta_func/ta_LINEARREG_SLOPE.c
# ta-lib/src/ta_func/ta_STOCHF.c
# ta-lib/src/ta_func/ta_MIN.c
# ta-lib/src/ta_func/ta_CDLIDENTICAL3CROWS.c
# ta-lib/src/ta_func/ta_CDLRICKSHAWMAN.c
# ta-lib/src/ta_func/ta_T3.c
# ta-lib/src/ta_func/ta_CDLMATHOLD.c
# ta-lib/src/ta_func/ta_CDLUNIQUE3RIVER.c
# ta-lib/src/ta_func/ta_ADOSC.c
# ta-lib/src/ta_func/ta_MAXINDEX.c
# ta-lib/src/ta_func/ta_ULTOSC.c
# ta-lib/src/ta_func/ta_TRIX.c
# ta-lib/src/ta_func/ta_MOM.c
# ta-lib/src/ta_func/ta_CDLDOJI.c
# ta-lib/src/ta_func/ta_EMA.c
# ta-lib/src/ta_func/ta_STOCHRSI.c
# ta-lib/src/ta_func/ta_ROC.c
# ta-lib/src/ta_func/ta_CDLEVENINGSTAR.c
# ta-lib/src/ta_func/ta_CDLCOUNTERATTACK.c
# ta-lib/src/ta_func/ta_LINEARREG_INTERCEPT.c
# ta-lib/src/ta_func/ta_SAREXT.c
# ta-lib/src/ta_func/ta_WILLR.c
# ta-lib/src/ta_func/ta_MULT.c
# ta-lib/src/ta_func/ta_ATR.c
# ta-lib/src/ta_func/ta_BOP.c
# ta-lib/src/ta_func/ta_CMO.c
# ta-lib/src/ta_func/ta_CDLONNECK.c
# ta-lib/src/ta_func/ta_CCI.c
# ta-lib/src/ta_func/ta_CDLLADDERBOTTOM.c
# ta-lib/src/ta_func/ta_HT_PHASOR.c
# ta-lib/src/ta_func/ta_utility.c
# ta-lib/src/ta_func/ta_PPO.c
# ta-lib/src/ta_func/ta_CDLHIKKAKE.c
# ta-lib/src/ta_func/ta_HT_DCPERIOD.c
# ta-lib/src/ta_func/ta_CDL3LINESTRIKE.c
# ta-lib/src/ta_func/ta_TEMA.c
# ta-lib/src/ta_func/ta_SIN.c
# ta-lib/src/ta_func/ta_MINUS_DI.c
# ta-lib/src/ta_func/ta_KAMA.c
# ta-lib/src/ta_func/ta_TANH.c
# ta-lib/src/ta_func/ta_CDLTAKURI.c
# ta-lib/src/ta_func/ta_CDLGRAVESTONEDOJI.c
# ta-lib/src/ta_common/
# ta-lib/src/ta_common/ta_pragma.h
# ta-lib/src/ta_common/ta_magic_nb.h
# ta-lib/src/ta_common/ta_retcode.csv
# ta-lib/src/ta_common/Makefile.in
# ta-lib/src/ta_common/Makefile.am
# ta-lib/src/ta_common/ta_memory.h
# ta-lib/src/ta_common/ta_version.c
# ta-lib/src/ta_common/ta_global.h
# ta-lib/src/ta_common/ta_global.c
# ta-lib/src/ta_common/ta_retcode.c
# ta-lib/src/Makefile.in
# ta-lib/src/ta_abstract/
# ta-lib/src/ta_abstract/frames/
# ta-lib/src/ta_abstract/frames/ta_frame.c
# ta-lib/src/ta_abstract/frames/ta_frame.h
# ta-lib/src/ta_abstract/excel_glue.c
# ta-lib/src/ta_abstract/ta_frame_priv.h
# ta-lib/src/ta_abstract/ta_func_api.c
# ta-lib/src/ta_abstract/Makefile.in
# ta-lib/src/ta_abstract/ta_def_ui.h
# ta-lib/src/ta_abstract/Makefile.am
# ta-lib/src/ta_abstract/ta_abstract.c
# ta-lib/src/ta_abstract/ta_group_idx.c
# ta-lib/src/ta_abstract/tables/
# ta-lib/src/ta_abstract/tables/table_u.c
# ta-lib/src/ta_abstract/tables/table_x.c
# ta-lib/src/ta_abstract/tables/table_r.c
# ta-lib/src/ta_abstract/tables/table_f.c
# ta-lib/src/ta_abstract/tables/table_j.c
# ta-lib/src/ta_abstract/tables/table_e.c
# ta-lib/src/ta_abstract/tables/table_t.c
# ta-lib/src/ta_abstract/tables/table_n.c
# ta-lib/src/ta_abstract/tables/table_i.c
# ta-lib/src/ta_abstract/tables/table_c.c
# ta-lib/src/ta_abstract/tables/table_l.c
# ta-lib/src/ta_abstract/tables/table_k.c
# ta-lib/src/ta_abstract/tables/table_g.c
# ta-lib/src/ta_abstract/tables/table_d.c
# ta-lib/src/ta_abstract/tables/table_h.c
# ta-lib/src/ta_abstract/tables/table_o.c
# ta-lib/src/ta_abstract/tables/table_b.c
# ta-lib/src/ta_abstract/tables/table_q.c
# ta-lib/src/ta_abstract/tables/table_v.c
# ta-lib/src/ta_abstract/tables/table_m.c
# ta-lib/src/ta_abstract/tables/table_s.c
# ta-lib/src/ta_abstract/tables/table_y.c
# ta-lib/src/ta_abstract/tables/table_p.c
# ta-lib/src/ta_abstract/tables/table_z.c
# ta-lib/src/ta_abstract/tables/table_a.c
# ta-lib/src/ta_abstract/tables/table_w.c
# ta-lib/src/ta_abstract/ta_def_ui.c
# ta-lib/src/ta_abstract/templates/
# ta-lib/src/ta_abstract/templates/ta_x.c.template
# ta-lib/src/ta_abstract/templates/ta_java_defs.h.template
# ta-lib/src/ta_abstract/templates/excel_glue.c.template
# ta-lib/src/ta_abstract/templates/ta_group_idx.c.template
# ta-lib/src/ta_abstract/templates/ta_frame.c.template
# ta-lib/src/ta_abstract/templates/CoreAnnotated.java.template
# ta-lib/src/ta_abstract/templates/ta_func.h.template
# ta-lib/src/ta_abstract/templates/ta_frame.h.template
# ta-lib/src/ta_abstract/templates/Makefile.am.template
# ta-lib/src/ta_abstract/templates/ta_func_api.c.template
# ta-lib/src/ta_abstract/templates/ta_func.swg.template
# ta-lib/src/ta_abstract/templates/ta_retcode.c.template
# ta-lib/src/ta_abstract/ta_java_defs.h
# ta-lib/src/Makefile.am
# ta-lib/src/tools/
# ta-lib/src/tools/ta_regtest/
# ta-lib/src/tools/ta_regtest/test_util.c
# ta-lib/src/tools/ta_regtest/ta_test_func.h
# ta-lib/src/tools/ta_regtest/test_data.c
# ta-lib/src/tools/ta_regtest/ta_gDataHigh.c
# ta-lib/src/tools/ta_regtest/Makefile.in
# ta-lib/src/tools/ta_regtest/test_internals.c
# ta-lib/src/tools/ta_regtest/Makefile.am
# ta-lib/src/tools/ta_regtest/ta_regtest.c
# ta-lib/src/tools/ta_regtest/ta_gDataOpen.c
# ta-lib/src/tools/ta_regtest/ta_gDataClose.c
# ta-lib/src/tools/ta_regtest/test_abstract.c
# ta-lib/src/tools/ta_regtest/ta_test_func/
# ta-lib/src/tools/ta_regtest/ta_test_func/test_bbands.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_stddev.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_1in_2out.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_sar.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_1in_1out.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_trange.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_macd.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_po.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hlc.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_mom.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_ohlc.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_adx.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_candlestick.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_rsi.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_ema.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_minmax.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hlcv.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hl.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_stoch.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_ma.c
# ta-lib/src/tools/ta_regtest/ta_error_number.h
# ta-lib/src/tools/ta_regtest/ta_test_priv.h
# ta-lib/src/tools/ta_regtest/ReadMe.txt
# ta-lib/src/tools/ta_regtest/ta_gDataLow.c
# ta-lib/src/tools/Makefile.in
# ta-lib/src/tools/Makefile.am
# ta-lib/src/tools/gen_code/
# ta-lib/src/tools/gen_code/java/
# ta-lib/src/tools/gen_code/java/PrettyCode.java
# ta-lib/src/tools/gen_code/java/Main.java
# ta-lib/src/tools/gen_code/gen_code.c
# ta-lib/src/tools/gen_code/Makefile.in
# ta-lib/src/tools/gen_code/Makefile.am
# ta-lib/src/tools/gen_code/mcpp.exe
# /content/ta-lib
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for /usr/bin/ld option to reload object files... -r
# checking for BSD-compatible nm... /usr/bin/nm -B
# checking whether ln -s works... yes
# checking how to recognise dependent libraries... pass_all
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking dlfcn.h usability... yes
# checking dlfcn.h presence... yes
# checking for dlfcn.h... yes
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking how to run the C++ preprocessor... g++ -E
# checking for g77... no
# checking for xlf... no
# checking for f77... f77
# checking whether we are using the GNU Fortran 77 compiler... yes
# checking whether f77 accepts -g... yes
# checking the maximum length of command line arguments... 32768
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for objdir... .libs
# checking for ar... ar
# checking for ranlib... ranlib
# checking for strip... strip
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC
# checking if gcc PIC flag -fPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# configure: creating libtool
# appending configuration tag "CXX" to libtool
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC
# checking if g++ PIC flag -fPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# appending configuration tag "F77" to libtool
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking for f77 option to produce PIC... -fPIC
# checking if f77 PIC flag -fPIC works... yes
# checking if f77 static flag -static works... yes
# checking if f77 supports -c -o file.o... yes
# checking whether the f77 linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for dlopen in -ldl... yes
# checking for pthread_create in -lpthread... yes
# checking for ANSI C header files... (cached) yes
# checking float.h usability... yes
# checking float.h presence... yes
# checking for float.h... yes
# checking for inttypes.h... (cached) yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking stddef.h usability... yes
# checking stddef.h presence... yes
# checking for stddef.h... yes
# checking for stdint.h... (cached) yes
# checking for stdlib.h... (cached) yes
# checking for string.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking wchar.h usability... yes
# checking wchar.h presence... yes
# checking for wchar.h... yes
# checking wctype.h usability... yes
# checking wctype.h presence... yes
# checking for wctype.h... yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking whether struct tm is in sys/time.h or time.h... time.h
# checking for working volatile... yes
# checking for ptrdiff_t... yes
# checking return type of signal handlers... void
# checking for working strcoll... yes
# checking for strftime... yes
# checking for working strtod... yes
# checking for vprintf... yes
# checking for _doprnt... no
# checking for floor... no
# checking for isascii... yes
# checking for localeconv... yes
# checking for mblen... yes
# checking for memmove... yes
# checking for memset... yes
# checking for modf... yes
# checking for pow... no
# checking for sqrt... no
# checking for strcasecmp... yes
# checking for strchr... yes
# checking for strerror... yes
# checking for strncasecmp... yes
# checking for strrchr... yes
# checking for strstr... yes
# checking for strtol... yes
# checking for strtoul... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/ta_abstract/Makefile
# config.status: creating src/ta_common/Makefile
# config.status: creating src/ta_func/Makefile
# config.status: creating src/tools/Makefile
# config.status: creating src/tools/gen_code/Makefile
# config.status: creating src/tools/ta_regtest/Makefile
# config.status: creating ta-lib-config
# config.status: creating ta-lib.spec
# config.status: creating ta-lib.dpkg
# config.status: creating include/ta_config.h
# config.status: include/ta_config.h is unchanged
# config.status: executing depfiles commands
# Making all in src
# make[1]: Entering directory '/content/ta-lib/src'
# Making all in ta_abstract
# make[2]: Entering directory '/content/ta-lib/src/ta_abstract'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/content/ta-lib/src/ta_abstract'
# Making all in ta_common
# make[2]: Entering directory '/content/ta-lib/src/ta_common'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/content/ta-lib/src/ta_common'
# Making all in ta_func
# make[2]: Entering directory '/content/ta-lib/src/ta_func'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/content/ta-lib/src/ta_func'
# make[2]: Entering directory '/content/ta-lib/src'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/content/ta-lib/src'
# make[1]: Leaving directory '/content/ta-lib/src'
# Making all in src/tools
# make[1]: Entering directory '/content/ta-lib/src/tools'
# Making all in gen_code
# make[2]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make  gen_code
# make[3]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make[3]: 'gen_code' is up to date.
# make[3]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# cp gen_code ../../../bin
# make[2]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# Making all in ta_regtest
# make[2]: Entering directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Entering directory '/content/ta-lib/src/tools'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Entering directory '/content/ta-lib'
# make[1]: Nothing to be done for 'all-am'.
# make[1]: Leaving directory '/content/ta-lib'
# Making install in src
# make[1]: Entering directory '/content/ta-lib/src'
# Making install in ta_abstract
# make[2]: Entering directory '/content/ta-lib/src/ta_abstract'
# make[3]: Entering directory '/content/ta-lib/src/ta_abstract'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
#  /usr/bin/install -c -m 644 '../../include/ta_defs.h' '/usr/include/ta-lib//ta_defs.h'
#  /usr/bin/install -c -m 644 '../../include/ta_libc.h' '/usr/include/ta-lib//ta_libc.h'
#  /usr/bin/install -c -m 644 '../../include/ta_abstract.h' '/usr/include/ta-lib//ta_abstract.h'
# make[3]: Leaving directory '/content/ta-lib/src/ta_abstract'
# make[2]: Leaving directory '/content/ta-lib/src/ta_abstract'
# Making install in ta_common
# make[2]: Entering directory '/content/ta-lib/src/ta_common'
# make[3]: Entering directory '/content/ta-lib/src/ta_common'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
#  /usr/bin/install -c -m 644 '../../include/ta_defs.h' '/usr/include/ta-lib//ta_defs.h'
#  /usr/bin/install -c -m 644 '../../include/ta_libc.h' '/usr/include/ta-lib//ta_libc.h'
#  /usr/bin/install -c -m 644 '../../include/ta_common.h' '/usr/include/ta-lib//ta_common.h'
# make[3]: Leaving directory '/content/ta-lib/src/ta_common'
# make[2]: Leaving directory '/content/ta-lib/src/ta_common'
# Making install in ta_func
# make[2]: Entering directory '/content/ta-lib/src/ta_func'
# make[3]: Entering directory '/content/ta-lib/src/ta_func'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
#  /usr/bin/install -c -m 644 '../../include/ta_defs.h' '/usr/include/ta-lib//ta_defs.h'
#  /usr/bin/install -c -m 644 '../../include/ta_libc.h' '/usr/include/ta-lib//ta_libc.h'
#  /usr/bin/install -c -m 644 '../../include/ta_func.h' '/usr/include/ta-lib//ta_func.h'
# make[3]: Leaving directory '/content/ta-lib/src/ta_func'
# make[2]: Leaving directory '/content/ta-lib/src/ta_func'
# make[2]: Entering directory '/content/ta-lib/src'
# make[3]: Entering directory '/content/ta-lib/src'
# test -z "/usr/lib" || /usr/bin/mkdir -p "/usr/lib"
#  /bin/bash ../libtool --mode=install /usr/bin/install -c  'libta_lib.la' '/usr/lib/libta_lib.la'
# /usr/bin/install -c .libs/libta_lib.so.0.0.0 /usr/lib/libta_lib.so.0.0.0
# (cd /usr/lib && { ln -s -f libta_lib.so.0.0.0 libta_lib.so.0 || { rm -f libta_lib.so.0 && ln -s libta_lib.so.0.0.0 libta_lib.so.0; }; })
# (cd /usr/lib && { ln -s -f libta_lib.so.0.0.0 libta_lib.so || { rm -f libta_lib.so && ln -s libta_lib.so.0.0.0 libta_lib.so; }; })
# /usr/bin/install -c .libs/libta_lib.lai /usr/lib/libta_lib.la
# /usr/bin/install -c .libs/libta_lib.a /usr/lib/libta_lib.a
# chmod 644 /usr/lib/libta_lib.a
# ranlib /usr/lib/libta_lib.a
# PATH="$PATH:/sbin" ldconfig -n /usr/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,--rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src'
# make[2]: Leaving directory '/content/ta-lib/src'
# make[1]: Leaving directory '/content/ta-lib/src'
# Making install in src/tools
# make[1]: Entering directory '/content/ta-lib/src/tools'
# Making install in gen_code
# make[2]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make  gen_code
# make[3]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make[3]: 'gen_code' is up to date.
# make[3]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# cp gen_code ../../../bin
# make[3]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# make[2]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# Making install in ta_regtest
# make[2]: Entering directory '/content/ta-lib/src/tools/ta_regtest'
# make[3]: Entering directory '/content/ta-lib/src/tools/ta_regtest'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Leaving directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Entering directory '/content/ta-lib/src/tools'
# make[3]: Entering directory '/content/ta-lib/src/tools'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src/tools'
# make[2]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Entering directory '/content/ta-lib'
# make[2]: Entering directory '/content/ta-lib'
# test -z "/usr/bin" || /usr/bin/mkdir -p "/usr/bin"
#  /usr/bin/install -c 'ta-lib-config' '/usr/bin/ta-lib-config'
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/content/ta-lib'
# make[1]: Leaving directory '/content/ta-lib'
# [Errno 2] No such file or directory: '/content # Change this to the appropriate directory if needed'
# /content/ta-lib
# Requirement already satisfied: TA-Lib in /usr/local/lib/python3.10/dist-packages (0.4.28)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from TA-Lib) (1.23.5)

# %%
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt

## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (4.1.1.post0)
# Requirement already satisfied: wrds in /usr/local/lib/python3.10/dist-packages (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from wrds) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from wrds) (1.5.3)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.10/dist-packages (from wrds) (2.9.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from wrds) (1.11.3)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.10/dist-packages (from wrds) (1.4.50)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2->wrds) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->wrds) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
# Requirement already satisfied: pyportfolioopt in /usr/local/lib/python3.10/dist-packages (1.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt) (1.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt) (1.5.3)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt) (1.11.3)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (3.2.4)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyportfolioopt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyportfolioopt) (2023.3.post1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.1.7.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.19->pyportfolioopt) (1.16.0)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-ncyjv2x4
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-ncyjv2x4
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 17a1fc057dcb6dac9641abf0987e5890ab70700c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-ytrozsi9/elegantrl_14dc1857e7df4fea85c1a2f8cf71ec53
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-ytrozsi9/elegantrl_14dc1857e7df4fea85c1a2f8cf71ec53
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit dde7ee4daa226450a43280e4ee02f1f23b565aa2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (3.0.2)
# Requirement already satisfied: ccxt<4,>=3 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (3.1.60)
# Requirement already satisfied: exchange-calendars<5,>=4 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (4.5)
# Requirement already satisfied: jqdatasdk<2,>=1 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (1.9.2)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (0.9.2)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (1.5.5)
# Requirement already satisfied: ray[default,tune]<3,>=2 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (2.8.0)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (1.2.2)
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a5 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (2.2.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (0.5.4)
# Requirement already satisfied: wrds<4,>=3 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (3.1.6)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (0.2.31)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.5.3)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.23.5)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.31.0)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.18)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.6.4)
# Requirement already satisfied: websockets<11,>=9.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: aiohttp==3.8.2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.8.2)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.1)
# Requirement already satisfied: multidict<6.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (5.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (67.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (2023.7.22)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (41.0.5)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2023.3)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.4.50)
# Requirement already satisfied: thriftpy2>=0.3.9 in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.17)
# Requirement already satisfied: pymysql>=0.7.6 in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.1.0)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2023.3.post1)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.11.3)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.2)
# Requirement already satisfied: empyrical>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.19.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.20.3)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (9.0.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2023.6.0)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.14)
# Requirement already satisfied: gpustat>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.3)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.10.13)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.18.0)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (6.4.0)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.21.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.59.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.2.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.29.1)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.8.0.76)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.14.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.7.0)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.4.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.10/dist-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.9)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.25.2)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.4.0)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.4)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.10/dist-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /usr/local/lib/python3.10/dist-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in /usr/local/lib/python3.10/dist-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.20.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.8.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (3.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.1)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.10/dist-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.7)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (3.11.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.3.5)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (4.1.1.post0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.12.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.11.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.1.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.61.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)

# %%
import finrl
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import yfinance as yf
import os
import talib
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes

# %%
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl import config_tickers
from finrl.main import check_and_make_directories
from finrl.config import TRAINED_MODEL_DIR, RESULTS_DIR
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
get_ipython().run_line_magic('matplotlib', 'inline')
from finrl.config import INDICATORS

check_and_make_directories([TRAINED_MODEL_DIR])


import itertools
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
config_tickers.DOW_30_TICKER
# Out:
# ['AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CSCO',
#  'CVX',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'KO',
#  'JPM',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'CRM',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT',
#  'DIS',
#  'DOW']

# %%
# Function to calculate KDJ
def calculate_kdj(df, n=9, m1=3, m2=3):
    low_list = df['low'].rolling(n).min()
    high_list = df['high'].rolling(n).max()
    rsv = (df['close'] - low_list) / (high_list - low_list) * 100
    k_values = rsv.ewm(span=m1, adjust=False).mean()
    d_values = k_values.ewm(span=m2, adjust=False).mean()
    j_values = 3 * k_values - 2 * d_values
    return k_values, d_values, j_values

# %%
TRAIN_START_DATE = '2013-01-01' #start date of training data
TRAIN_END_DATE = '2018-01-01'   #end date of training data
TRADE_START_DATE = '2018-01-01' #start date of trading data
TRADE_END_DATE = '2022-12-31'   #end date of trading data

# %%
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
df_raw.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (73977, 8)
#          date       open       high        low      close     volume   tic  \
# 0  2013-01-02  19.779285  19.821428  19.343929  16.769094  560518000  AAPL
# 1  2013-01-02  87.360001  89.239998  87.290001  66.515793    5772800  AMGN
# 2  2013-01-02  58.330002  58.950001  58.310001  50.327698    6091400   AXP
# 3  2013-01-02  76.550003  77.330002  76.449997  64.583847    5036400    BA
# 4  2013-01-02  92.949997  94.440002  92.949997  69.443253   11590000   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
df_raw.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (73977, 8)
#          date       open       high        low      close     volume   tic  \
# 0  2013-01-02  19.779285  19.821428  19.343929  16.769094  560518000  AAPL
# 1  2013-01-02  87.360001  89.239998  87.290001  66.515793    5772800  AMGN
# 2  2013-01-02  58.330002  58.950001  58.310001  50.327698    6091400   AXP
# 3  2013-01-02  76.550003  77.330002  76.449997  64.583847    5036400    BA
# 4  2013-01-02  92.949997  94.440002  92.949997  69.443253   11590000   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
#Preprocess Data

fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=True,
                     user_defined_feature = False)
processed = fe.preprocess_data(df_raw)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Successfully added technical indicators
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2517, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])
# Calculate KDJ and add to the dataframe
n = 9  # Period for calculating KDJ
m1 = 3  # Smoothing period for %K
m2 = 3  # Smoothing period for %D

k_values, d_values, j_values = calculate_kdj(processed_full, n, m1, m2)
processed_full['k_values'] = k_values
processed_full['d_values'] = d_values
processed_full['j_values'] = j_values

processed_full = processed_full.fillna(0)
processed_full.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          date   tic       open       high        low      close       volume  \
# 0  2013-01-02  AAPL  19.779285  19.821428  19.343929  16.769094  560518000.0
# 1  2013-01-02  AMGN  87.360001  89.239998  87.290001  66.515793    5772800.0
# 2  2013-01-02   AXP  58.330002  58.950001  58.310001  50.327698    6091400.0
# 3  2013-01-02    BA  76.550003  77.330002  76.449997  64.583847    5036400.0
# 4  2013-01-02   CAT  92.949997  94.440002  92.949997  69.443253   11590000.0
#
#    day  macd    boll_ub  ...  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  2.0   0.0  16.962604  ...     0.0 -66.666667  100.0     16.769094
# 1  2.0   0.0  16.962604  ...     0.0 -66.666667  100.0     66.515793
# 2  2.0   0.0  16.962604  ...     0.0 -66.666667  100.0     50.327698
# 3  2.0   0.0  16.962604  ...     0.0 -66.666667  100.0     64.583847
# 4  2.0   0.0  16.962604  ...     0.0 -66.666667  100.0     69.443253
#
#    close_60_sma    vix  turbulence  k_values  d_values  j_values
# 0     16.769094  14.68         0.0       0.0       0.0       0.0
# 1     66.515793  14.68         0.0       0.0       0.0       0.0
# 2     50.327698  14.68         0.0       0.0       0.0       0.0
# 3     64.583847  14.68         0.0       0.0       0.0       0.0
# 4     69.443253  14.68         0.0       0.0       0.0       0.0
#
# [5 rows x 21 columns]

# %%
#Split the data for training and trading
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 36511
# 36482
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train.to_csv('train_data.csv')
trade.to_csv('trade_data.csv')
train = pd.read_csv('train_data.csv')
train = train.set_index(train.columns[0])
train.index.names = ['']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Construct the environment
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
#Environment for training
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %%
#Train DRL Agents
agent = DRLAgent(env = env_train)

# %%
# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True
if_using_dqn = True

# %%
# ### Agent 1: A2C

agent = DRLAgent(env = env_train)
A2C_PARAMS = {
    "n_steps": 1088,
    "ent_coef": 0.0055,
    "learning_rate": 0.00505,
}

model_a2c = agent.get_model("a2c",model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
trained_a2c = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
# Out:
# {'n_steps': 1088, 'ent_coef': 0.0055, 'learning_rate': 0.00505}
# Using cpu device
# Logging to results/a2c
# day: 1258, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2148176.32
# total_reward: 1148176.32
# total_cost: 4359.08
# total_trades: 23746
# Sharpe: 1.378
# =================================
# day: 1258, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 2177776.31
# total_reward: 1177776.31
# total_cost: 7360.58
# total_trades: 16186
# Sharpe: 1.260
# =================================
# day: 1258, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1911978.38
# total_reward: 911978.38
# total_cost: 5762.84
# total_trades: 16731
# Sharpe: 1.157
# =================================
# day: 1258, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1809853.17
# total_reward: 809853.17
# total_cost: 5090.60
# total_trades: 17198
# Sharpe: 0.996
# =================================

# %%
# ### Agent 2: DDPG
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {
    "buffer_size": 550000,
    "learning_rate": 0.00505,
    "batch_size": 160,
}
model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)

trained_ddpg = agent.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
# Out:
# {'buffer_size': 550000, 'learning_rate': 0.00505, 'batch_size': 160}
# Using cpu device
# Logging to results/ddpg
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 26         |
# |    time_elapsed    | 188        |
# |    total_timesteps | 5036       |
# | train/             |            |
# |    actor_loss      | 51         |
# |    critic_loss     | 1.45e+03   |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 3777       |
# |    reward          | -1.1738276 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 23         |
# |    time_elapsed    | 434        |
# |    total_timesteps | 10072      |
# | train/             |            |
# |    actor_loss      | -11.5      |
# |    critic_loss     | 79.6       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 8813       |
# |    reward          | -1.1738276 |
# -----------------------------------
# day: 1258, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 2298169.51
# total_reward: 1298169.51
# total_cost: 999.00
# total_trades: 26408
# Sharpe: 1.425
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 22         |
# |    time_elapsed    | 682        |
# |    total_timesteps | 15108      |
# | train/             |            |
# |    actor_loss      | -12.3      |
# |    critic_loss     | 0.905      |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 13849      |
# |    reward          | -1.1738276 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 21         |
# |    time_elapsed    | 929        |
# |    total_timesteps | 20144      |
# | train/             |            |
# |    actor_loss      | -11.8      |
# |    critic_loss     | 0.939      |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 18885      |
# |    reward          | -1.1738276 |
# -----------------------------------
# day: 1258, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2298169.51
# total_reward: 1298169.51
# total_cost: 999.00
# total_trades: 26408
# Sharpe: 1.425
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 21         |
# |    time_elapsed    | 1173       |
# |    total_timesteps | 25180      |
# | train/             |            |
# |    actor_loss      | -11        |
# |    critic_loss     | 0.767      |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 23921      |
# |    reward          | -1.1738276 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 24         |
# |    fps             | 21         |
# |    time_elapsed    | 1424       |
# |    total_timesteps | 30216      |
# | train/             |            |
# |    actor_loss      | -10.5      |
# |    critic_loss     | 0.653      |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 28957      |
# |    reward          | -1.1738276 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 28         |
# |    fps             | 21         |
# |    time_elapsed    | 1678       |
# |    total_timesteps | 35252      |
# | train/             |            |
# |    actor_loss      | -8.09      |
# |    critic_loss     | 9.47       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 33993      |
# |    reward          | -1.1738276 |
# -----------------------------------
# day: 1258, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 2298169.51
# total_reward: 1298169.51
# total_cost: 999.00
# total_trades: 26408
# Sharpe: 1.425
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 32         |
# |    fps             | 20         |
# |    time_elapsed    | 1932       |
# |    total_timesteps | 40288      |
# | train/             |            |
# |    actor_loss      | -3.82      |
# |    critic_loss     | 1.21       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 39029      |
# |    reward          | -1.1738276 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 36         |
# |    fps             | 20         |
# |    time_elapsed    | 2186       |
# |    total_timesteps | 45324      |
# | train/             |            |
# |    actor_loss      | -5.06      |
# |    critic_loss     | 1.21       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 44065      |
# |    reward          | -1.1738276 |
# -----------------------------------
# day: 1258, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 2298169.51
# total_reward: 1298169.51
# total_cost: 999.00
# total_trades: 26408
# Sharpe: 1.425
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 40         |
# |    fps             | 20         |
# |    time_elapsed    | 2441       |
# |    total_timesteps | 50360      |
# | train/             |            |
# |    actor_loss      | -5.99      |
# |    critic_loss     | 1.21       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 49101      |
# |    reward          | -1.1738276 |
# -----------------------------------

# %%
#### Agent 3: PPO
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 1088,
    "ent_coef": 0.0055,
    "learning_rate": 0.00505,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)


trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None


trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
# Out:
# {'n_steps': 1088, 'ent_coef': 0.0055, 'learning_rate': 0.00505}
# Using cpu device
# Logging to results/ppo
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -----------------------------------
# | time/              |            |
# |    fps             | 161        |
# |    iterations      | 1          |
# |    time_elapsed    | 6          |
# |    total_timesteps | 1088       |
# | train/             |            |
# |    reward          | -0.3900282 |
# -----------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 126      |
# |    iterations           | 2        |
# |    time_elapsed         | 17       |
# |    total_timesteps      | 2176     |
# | train/                  |          |
# |    approx_kl            | 9.225487 |
# |    clip_fraction        | 0.958    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -42.5    |
# |    explained_variance   | -0.0422  |
# |    learning_rate        | 0.00505  |
# |    loss                 | 1.99     |
# |    n_updates            | 10       |
# |    policy_gradient_loss | 0.336    |
# |    reward               | 0.133069 |
# |    std                  | 1.11     |
# |    value_loss           | 4.06     |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 3          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 3264       |
# | train/                  |            |
# |    approx_kl            | 27.381708  |
# |    clip_fraction        | 0.98       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -46.3      |
# |    explained_variance   | 0.125      |
# |    learning_rate        | 0.00505    |
# |    loss                 | 4.46       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.298      |
# |    reward               | -2.6298406 |
# |    std                  | 1.35       |
# |    value_loss           | 8.48       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 40.370594   |
# |    clip_fraction        | 0.978       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52.6       |
# |    explained_variance   | -0.0196     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 2.96        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.302       |
# |    reward               | -0.08322999 |
# |    std                  | 1.7         |
# |    value_loss           | 7.93        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 5           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 5440        |
# | train/                  |             |
# |    approx_kl            | 24.195127   |
# |    clip_fraction        | 0.971       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -58.7       |
# |    explained_variance   | -0.0343     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 2.98        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.328       |
# |    reward               | -0.12301661 |
# |    std                  | 2.07        |
# |    value_loss           | 7.98        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 6          |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 6528       |
# | train/                  |            |
# |    approx_kl            | 33.889923  |
# |    clip_fraction        | 0.952      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -63.8      |
# |    explained_variance   | -0.0909    |
# |    learning_rate        | 0.00505    |
# |    loss                 | 5.73       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.271      |
# |    reward               | -0.5389921 |
# |    std                  | 2.51       |
# |    value_loss           | 13.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 122        |
# |    iterations           | 7          |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 7616       |
# | train/                  |            |
# |    approx_kl            | 16.73843   |
# |    clip_fraction        | 0.958      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -69.9      |
# |    explained_variance   | 0.0398     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.64       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.314      |
# |    reward               | -1.0845754 |
# |    std                  | 3.13       |
# |    value_loss           | 7.3        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 122        |
# |    iterations           | 8          |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 3.4947326  |
# |    clip_fraction        | 0.957      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -76        |
# |    explained_variance   | 0.0449     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 4.49       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | 0.286      |
# |    reward               | 0.13969882 |
# |    std                  | 3.72       |
# |    value_loss           | 8.3        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 9          |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 9792       |
# | train/                  |            |
# |    approx_kl            | 1.2929341  |
# |    clip_fraction        | 0.899      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -79.4      |
# |    explained_variance   | 0.0214     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.33       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.217      |
# |    reward               | -0.9876237 |
# |    std                  | 4.07       |
# |    value_loss           | 6.44       |
# ----------------------------------------
# day: 1258, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1712834.83
# total_reward: 712834.83
# total_cost: 6648.49
# total_trades: 21529
# Sharpe: 0.936
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 122        |
# |    iterations           | 10         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 10880      |
# | train/                  |            |
# |    approx_kl            | 0.58250487 |
# |    clip_fraction        | 0.881      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -81.5      |
# |    explained_variance   | 0.0199     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.34       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.21       |
# |    reward               | 0.2966432  |
# |    std                  | 4.26       |
# |    value_loss           | 7.89       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 11         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 11968      |
# | train/                  |            |
# |    approx_kl            | 0.20218432 |
# |    clip_fraction        | 0.767      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -82.5      |
# |    explained_variance   | 0.0159     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.53       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.113      |
# |    reward               | -0.3018818 |
# |    std                  | 4.34       |
# |    value_loss           | 7.16       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 12         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 13056      |
# | train/                  |            |
# |    approx_kl            | 0.27360368 |
# |    clip_fraction        | 0.729      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -82.6      |
# |    explained_variance   | 0.00978    |
# |    learning_rate        | 0.00505    |
# |    loss                 | 1.57       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.089      |
# |    reward               | 0.10680496 |
# |    std                  | 4.38       |
# |    value_loss           | 6.18       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 13         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 14144      |
# | train/                  |            |
# |    approx_kl            | 0.15626535 |
# |    clip_fraction        | 0.726      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -83.1      |
# |    explained_variance   | 0.0141     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.01       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0912     |
# |    reward               | 0.5955847  |
# |    std                  | 4.44       |
# |    value_loss           | 6.73       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 14         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 15232      |
# | train/                  |            |
# |    approx_kl            | 0.24604304 |
# |    clip_fraction        | 0.725      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -83.4      |
# |    explained_variance   | 0.0191     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 4.07       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0852     |
# |    reward               | 0.4252784  |
# |    std                  | 4.51       |
# |    value_loss           | 7.85       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 15         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 16320      |
# | train/                  |            |
# |    approx_kl            | 0.24251705 |
# |    clip_fraction        | 0.688      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -84        |
# |    explained_variance   | 0.0339     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.06       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0645     |
# |    reward               | -0.527946  |
# |    std                  | 4.57       |
# |    value_loss           | 7.76       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 16         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.15864755 |
# |    clip_fraction        | 0.697      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -84.4      |
# |    explained_variance   | 4.89e-06   |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.74       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0798     |
# |    reward               | 2.3225625  |
# |    std                  | 4.65       |
# |    value_loss           | 7.01       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 17         |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 18496      |
# | train/                  |            |
# |    approx_kl            | 0.12312592 |
# |    clip_fraction        | 0.69       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -84.7      |
# |    explained_variance   | 0.0636     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.16       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0661     |
# |    reward               | 0.42651823 |
# |    std                  | 4.69       |
# |    value_loss           | 6.59       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 18          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 19584       |
# | train/                  |             |
# |    approx_kl            | 0.100753844 |
# |    clip_fraction        | 0.63        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -85         |
# |    explained_variance   | 0.0769      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 3.28        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0515      |
# |    reward               | 0.39954793  |
# |    std                  | 4.72        |
# |    value_loss           | 7.94        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 19           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 20672        |
# | train/                  |              |
# |    approx_kl            | 0.12585574   |
# |    clip_fraction        | 0.656        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -85.1        |
# |    explained_variance   | 0.0964       |
# |    learning_rate        | 0.00505      |
# |    loss                 | 2.09         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.0643       |
# |    reward               | -0.090669386 |
# |    std                  | 4.76         |
# |    value_loss           | 7.19         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 20         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 21760      |
# | train/                  |            |
# |    approx_kl            | 0.11397155 |
# |    clip_fraction        | 0.654      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -85.2      |
# |    explained_variance   | 0.0806     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.24       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0583     |
# |    reward               | 0.44405732 |
# |    std                  | 4.79       |
# |    value_loss           | 5.92       |
# ----------------------------------------
# day: 1258, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1665132.59
# total_reward: 665132.59
# total_cost: 7480.33
# total_trades: 20449
# Sharpe: 0.873
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 21          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 22848       |
# | train/                  |             |
# |    approx_kl            | 0.12918875  |
# |    clip_fraction        | 0.657       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -85.3       |
# |    explained_variance   | 0.0951      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 2.51        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0461      |
# |    reward               | -0.61708057 |
# |    std                  | 4.82        |
# |    value_loss           | 7.04        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 22         |
# |    time_elapsed         | 201        |
# |    total_timesteps      | 23936      |
# | train/                  |            |
# |    approx_kl            | 0.19180498 |
# |    clip_fraction        | 0.651      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -85.6      |
# |    explained_variance   | 0.1        |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.65       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0571     |
# |    reward               | 0.06010715 |
# |    std                  | 4.85       |
# |    value_loss           | 7.61       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 23         |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 25024      |
# | train/                  |            |
# |    approx_kl            | 0.09942525 |
# |    clip_fraction        | 0.635      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -85.9      |
# |    explained_variance   | 0.0279     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.1        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0582     |
# |    reward               | 1.1250283  |
# |    std                  | 4.91       |
# |    value_loss           | 7.88       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 24         |
# |    time_elapsed         | 219        |
# |    total_timesteps      | 26112      |
# | train/                  |            |
# |    approx_kl            | 0.10921938 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -86.2      |
# |    explained_variance   | 0.117      |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.38       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0592     |
# |    reward               | -0.1212507 |
# |    std                  | 4.94       |
# |    value_loss           | 6.06       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 119       |
# |    iterations           | 25        |
# |    time_elapsed         | 228       |
# |    total_timesteps      | 27200     |
# | train/                  |           |
# |    approx_kl            | 0.0980025 |
# |    clip_fraction        | 0.636     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -86.3     |
# |    explained_variance   | 0.12      |
# |    learning_rate        | 0.00505   |
# |    loss                 | 2.92      |
# |    n_updates            | 240       |
# |    policy_gradient_loss | 0.0486    |
# |    reward               | 0.6556789 |
# |    std                  | 4.95      |
# |    value_loss           | 6.98      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 26         |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 28288      |
# | train/                  |            |
# |    approx_kl            | 0.15080512 |
# |    clip_fraction        | 0.646      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -86.6      |
# |    explained_variance   | 0.0885     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.51       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0594     |
# |    reward               | 0.6924961  |
# |    std                  | 5.01       |
# |    value_loss           | 7.31       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 27         |
# |    time_elapsed         | 251        |
# |    total_timesteps      | 29376      |
# | train/                  |            |
# |    approx_kl            | 0.08428933 |
# |    clip_fraction        | 0.626      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -86.7      |
# |    explained_variance   | 0.0691     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.06       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0542     |
# |    reward               | 0.18438357 |
# |    std                  | 5.01       |
# |    value_loss           | 5.99       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 28          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 30464       |
# | train/                  |             |
# |    approx_kl            | 0.108751394 |
# |    clip_fraction        | 0.63        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -86.7       |
# |    explained_variance   | 0.0659      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 1.79        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0501      |
# |    reward               | 0.5336816   |
# |    std                  | 5.06        |
# |    value_loss           | 5.69        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 29          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 31552       |
# | train/                  |             |
# |    approx_kl            | 0.080404386 |
# |    clip_fraction        | 0.609       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -86.9       |
# |    explained_variance   | 0.0788      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 3.58        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0468      |
# |    reward               | -0.6859383  |
# |    std                  | 5.07        |
# |    value_loss           | 7.06        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 30         |
# |    time_elapsed         | 280        |
# |    total_timesteps      | 32640      |
# | train/                  |            |
# |    approx_kl            | 0.10129716 |
# |    clip_fraction        | 0.602      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.1      |
# |    explained_variance   | 0.086      |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.71       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0491     |
# |    reward               | -1.7541554 |
# |    std                  | 5.11       |
# |    value_loss           | 7.04       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 31          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 33728       |
# | train/                  |             |
# |    approx_kl            | 0.099710606 |
# |    clip_fraction        | 0.632       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -87.3       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.00505     |
# |    loss                 | 3.03        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0574      |
# |    reward               | 2.1488442   |
# |    std                  | 5.14        |
# |    value_loss           | 6.27        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 32          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.0843731   |
# |    clip_fraction        | 0.596       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -87.5       |
# |    explained_variance   | 0.089       |
# |    learning_rate        | 0.00505     |
# |    loss                 | 2.36        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0543      |
# |    reward               | -0.11649936 |
# |    std                  | 5.17        |
# |    value_loss           | 6.68        |
# -----------------------------------------
# day: 1258, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1708939.16
# total_reward: 708939.16
# total_cost: 8955.06
# total_trades: 20407
# Sharpe: 0.952
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 33         |
# |    time_elapsed         | 307        |
# |    total_timesteps      | 35904      |
# | train/                  |            |
# |    approx_kl            | 0.08429336 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.7      |
# |    explained_variance   | 0.0849     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.93       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0395     |
# |    reward               | 1.161876   |
# |    std                  | 5.22       |
# |    value_loss           | 6.82       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 34         |
# |    time_elapsed         | 316        |
# |    total_timesteps      | 36992      |
# | train/                  |            |
# |    approx_kl            | 0.16672248 |
# |    clip_fraction        | 0.617      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.7      |
# |    explained_variance   | 0.0875     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.66       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0473     |
# |    reward               | 2.6399527  |
# |    std                  | 5.21       |
# |    value_loss           | 6.44       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 35         |
# |    time_elapsed         | 326        |
# |    total_timesteps      | 38080      |
# | train/                  |            |
# |    approx_kl            | 0.13319305 |
# |    clip_fraction        | 0.622      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -87.9      |
# |    explained_variance   | 0.0805     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.05       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0443     |
# |    reward               | 0.10295599 |
# |    std                  | 5.23       |
# |    value_loss           | 5.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 36         |
# |    time_elapsed         | 334        |
# |    total_timesteps      | 39168      |
# | train/                  |            |
# |    approx_kl            | 0.1022684  |
# |    clip_fraction        | 0.636      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -88        |
# |    explained_variance   | 0.105      |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.3        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.043      |
# |    reward               | 0.43431312 |
# |    std                  | 5.25       |
# |    value_loss           | 6.67       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 37          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 40256       |
# | train/                  |             |
# |    approx_kl            | 0.17300458  |
# |    clip_fraction        | 0.616       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88         |
# |    explained_variance   | 0.0862      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 4.91        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0385      |
# |    reward               | -0.15439564 |
# |    std                  | 5.24        |
# |    value_loss           | 6.99        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 38         |
# |    time_elapsed         | 352        |
# |    total_timesteps      | 41344      |
# | train/                  |            |
# |    approx_kl            | 0.09358545 |
# |    clip_fraction        | 0.615      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -88        |
# |    explained_variance   | 1.25e-06   |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.34       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0461     |
# |    reward               | 0.94215107 |
# |    std                  | 5.24       |
# |    value_loss           | 6.92       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 39         |
# |    time_elapsed         | 363        |
# |    total_timesteps      | 42432      |
# | train/                  |            |
# |    approx_kl            | 0.11065477 |
# |    clip_fraction        | 0.587      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -88.1      |
# |    explained_variance   | 0.1        |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.64       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0438     |
# |    reward               | 0.8051664  |
# |    std                  | 5.26       |
# |    value_loss           | 6.15       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 40          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.122793615 |
# |    clip_fraction        | 0.593       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88.2       |
# |    explained_variance   | 0.0722      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 3.04        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.047       |
# |    reward               | 0.87039495  |
# |    std                  | 5.27        |
# |    value_loss           | 8.12        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 41         |
# |    time_elapsed         | 381        |
# |    total_timesteps      | 44608      |
# | train/                  |            |
# |    approx_kl            | 0.08023692 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -88.3      |
# |    explained_variance   | 0.0961     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.78       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0454     |
# |    reward               | 0.14915289 |
# |    std                  | 5.32       |
# |    value_loss           | 8.44       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 42          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 45696       |
# | train/                  |             |
# |    approx_kl            | 0.09756061  |
# |    clip_fraction        | 0.577       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88.6       |
# |    explained_variance   | 0.007       |
# |    learning_rate        | 0.00505     |
# |    loss                 | 3.87        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0391      |
# |    reward               | -0.07823011 |
# |    std                  | 5.37        |
# |    value_loss           | 6.58        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 43          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 46784       |
# | train/                  |             |
# |    approx_kl            | 0.116174966 |
# |    clip_fraction        | 0.605       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88.7       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 5.92        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0365      |
# |    reward               | 0.110680096 |
# |    std                  | 5.42        |
# |    value_loss           | 9.18        |
# -----------------------------------------
# day: 1258, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 1775486.46
# total_reward: 775486.46
# total_cost: 9568.43
# total_trades: 20420
# Sharpe: 0.958
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 44          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 47872       |
# | train/                  |             |
# |    approx_kl            | 0.095984615 |
# |    clip_fraction        | 0.599       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -89.1       |
# |    explained_variance   | 0.0378      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 5.32        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0337      |
# |    reward               | -0.06758707 |
# |    std                  | 5.46        |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 45         |
# |    time_elapsed         | 417        |
# |    total_timesteps      | 48960      |
# | train/                  |            |
# |    approx_kl            | 0.10356081 |
# |    clip_fraction        | 0.609      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -89.3      |
# |    explained_variance   | 0.0117     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.41       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0431     |
# |    reward               | -0.1858878 |
# |    std                  | 5.54       |
# |    value_loss           | 8.47       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 46          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 50048       |
# | train/                  |             |
# |    approx_kl            | 0.09362232  |
# |    clip_fraction        | 0.594       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -89.7       |
# |    explained_variance   | 0.0035      |
# |    learning_rate        | 0.00505     |
# |    loss                 | 3.17        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0436      |
# |    reward               | -0.31368002 |
# |    std                  | 5.58        |
# |    value_loss           | 6.13        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 47         |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 51136      |
# | train/                  |            |
# |    approx_kl            | 0.07645743 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -89.8      |
# |    explained_variance   | 0.0304     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.29       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0357     |
# |    reward               | -1.5237362 |
# |    std                  | 5.62       |
# |    value_loss           | 6.99       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 48         |
# |    time_elapsed         | 445        |
# |    total_timesteps      | 52224      |
# | train/                  |            |
# |    approx_kl            | 0.12261629 |
# |    clip_fraction        | 0.619      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -90.1      |
# |    explained_variance   | 0.028      |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.29       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0415     |
# |    reward               | -0.8586036 |
# |    std                  | 5.7        |
# |    value_loss           | 7.05       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 49         |
# |    time_elapsed         | 453        |
# |    total_timesteps      | 53312      |
# | train/                  |            |
# |    approx_kl            | 0.07898073 |
# |    clip_fraction        | 0.61       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -90.5      |
# |    explained_variance   | 0.0246     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.24       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0464     |
# |    reward               | -1.0326761 |
# |    std                  | 5.77       |
# |    value_loss           | 6.52       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 50         |
# |    time_elapsed         | 463        |
# |    total_timesteps      | 54400      |
# | train/                  |            |
# |    approx_kl            | 0.11609236 |
# |    clip_fraction        | 0.627      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -90.6      |
# |    explained_variance   | 0.0163     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.41       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0449     |
# |    reward               | 1.0046612  |
# |    std                  | 5.8        |
# |    value_loss           | 6.33       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 51        |
# |    time_elapsed         | 471       |
# |    total_timesteps      | 55488     |
# | train/                  |           |
# |    approx_kl            | 0.0882976 |
# |    clip_fraction        | 0.6       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -90.9     |
# |    explained_variance   | 0.0178    |
# |    learning_rate        | 0.00505   |
# |    loss                 | 4.53      |
# |    n_updates            | 500       |
# |    policy_gradient_loss | 0.0425    |
# |    reward               | 1.2304066 |
# |    std                  | 5.85      |
# |    value_loss           | 7.7       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 52         |
# |    time_elapsed         | 482        |
# |    total_timesteps      | 56576      |
# | train/                  |            |
# |    approx_kl            | 0.09310707 |
# |    clip_fraction        | 0.616      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.4      |
# |    explained_variance   | 0.0254     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 4.86       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0311     |
# |    reward               | -1.3847933 |
# |    std                  | 5.94       |
# |    value_loss           | 7.2        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 53         |
# |    time_elapsed         | 489        |
# |    total_timesteps      | 57664      |
# | train/                  |            |
# |    approx_kl            | 0.10915861 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.5      |
# |    explained_variance   | -9.3e-06   |
# |    learning_rate        | 0.00505    |
# |    loss                 | 2.41       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0352     |
# |    reward               | 0.4577908  |
# |    std                  | 5.97       |
# |    value_loss           | 6.17       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 54         |
# |    time_elapsed         | 500        |
# |    total_timesteps      | 58752      |
# | train/                  |            |
# |    approx_kl            | 0.06391141 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.7      |
# |    explained_variance   | 0.0469     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.09       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0371     |
# |    reward               | 1.0261519  |
# |    std                  | 6          |
# |    value_loss           | 6.05       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 55         |
# |    time_elapsed         | 508        |
# |    total_timesteps      | 59840      |
# | train/                  |            |
# |    approx_kl            | 0.07145023 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.9      |
# |    explained_variance   | 0.0291     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.37       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.0467     |
# |    reward               | 4.1962786  |
# |    std                  | 6.06       |
# |    value_loss           | 6.53       |
# ----------------------------------------
# day: 1258, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1702230.51
# total_reward: 702230.51
# total_cost: 10509.56
# total_trades: 21237
# Sharpe: 0.964
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 56         |
# |    time_elapsed         | 521        |
# |    total_timesteps      | 60928      |
# | train/                  |            |
# |    approx_kl            | 0.08488817 |
# |    clip_fraction        | 0.607      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.3      |
# |    explained_variance   | 0.038      |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.71       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.0343     |
# |    reward               | -1.0238734 |
# |    std                  | 6.15       |
# |    value_loss           | 6.37       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 116        |
# |    iterations           | 57         |
# |    time_elapsed         | 532        |
# |    total_timesteps      | 62016      |
# | train/                  |            |
# |    approx_kl            | 0.08075313 |
# |    clip_fraction        | 0.572      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -92.6      |
# |    explained_variance   | 0.0207     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 3.3        |
# |    n_updates            | 560        |
# |    policy_gradient_loss | 0.0325     |
# |    reward               | -0.1037965 |
# |    std                  | 6.19       |
# |    value_loss           | 5.88       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# ...
# | train/                  |            |
# |    approx_kl            | 0.04075482 |
# |    clip_fraction        | 0.474      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -110       |
# |    explained_variance   | 0.0114     |
# |    learning_rate        | 0.00505    |
# |    loss                 | 6          |
# |    n_updates            | 1650       |
# |    policy_gradient_loss | 0.00936    |
# |    reward               | 0.4742504  |
# |    std                  | 11.4       |
# |    value_loss           | 11.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 167         |
# |    time_elapsed         | 1574        |
# |    total_timesteps      | 181696      |
# | train/                  |             |
# |    approx_kl            | 0.038623903 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.00555     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 6.48        |
# |    n_updates            | 1660        |
# |    policy_gradient_loss | 0.0104      |
# |    reward               | -0.94864583 |
# |    std                  | 11.6        |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 168         |
# |    time_elapsed         | 1584        |
# |    total_timesteps      | 182784      |
# | train/                  |             |
# |    approx_kl            | 0.044341795 |
# |    clip_fraction        | 0.488       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.00309     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 5.76        |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | 0.0163      |
# |    reward               | 0.5705395   |
# |    std                  | 11.7        |
# |    value_loss           | 12.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 169         |
# |    time_elapsed         | 1593        |
# |    total_timesteps      | 183872      |
# | train/                  |             |
# |    approx_kl            | 0.042928502 |
# |    clip_fraction        | 0.454       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0.00457     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 8.81        |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | 0.00514     |
# |    reward               | 0.20504235  |
# |    std                  | 11.7        |
# |    value_loss           | 15          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 170        |
# |    time_elapsed         | 1602       |
# |    total_timesteps      | 184960     |
# | train/                  |            |
# |    approx_kl            | 0.04582334 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0.00271    |
# |    learning_rate        | 0.00505    |
# |    loss                 | 9.84       |
# |    n_updates            | 1690       |
# |    policy_gradient_loss | 0.00767    |
# |    reward               | -1.8507254 |
# |    std                  | 11.8       |
# |    value_loss           | 17.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 171        |
# |    time_elapsed         | 1612       |
# |    total_timesteps      | 186048     |
# | train/                  |            |
# |    approx_kl            | 0.04813314 |
# |    clip_fraction        | 0.458      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -112       |
# |    explained_variance   | -0.000748  |
# |    learning_rate        | 0.00505    |
# |    loss                 | 4.22       |
# |    n_updates            | 1700       |
# |    policy_gradient_loss | 0.0099     |
# |    reward               | -3.3332026 |
# |    std                  | 11.9       |
# |    value_loss           | 12.6       |
# ----------------------------------------
# day: 1258, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 2230688.48
# total_reward: 1230688.48
# total_cost: 39827.51
# total_trades: 21333
# Sharpe: 1.035
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 172         |
# |    time_elapsed         | 1620        |
# |    total_timesteps      | 187136      |
# | train/                  |             |
# |    approx_kl            | 0.047180146 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0.00422     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 8.93        |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | 0.00664     |
# |    reward               | 0.4619221   |
# |    std                  | 11.9        |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 173         |
# |    time_elapsed         | 1631        |
# |    total_timesteps      | 188224      |
# | train/                  |             |
# |    approx_kl            | 0.041319355 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0.00157     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 4.96        |
# |    n_updates            | 1720        |
# |    policy_gradient_loss | 0.00406     |
# |    reward               | 0.94719404  |
# |    std                  | 12          |
# |    value_loss           | 13.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 174        |
# |    time_elapsed         | 1639       |
# |    total_timesteps      | 189312     |
# | train/                  |            |
# |    approx_kl            | 0.05073747 |
# |    clip_fraction        | 0.428      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -112       |
# |    explained_variance   | 0.00371    |
# |    learning_rate        | 0.00505    |
# |    loss                 | 5.6        |
# |    n_updates            | 1730       |
# |    policy_gradient_loss | 0.0145     |
# |    reward               | 2.7894008  |
# |    std                  | 12.1       |
# |    value_loss           | 11.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 175         |
# |    time_elapsed         | 1649        |
# |    total_timesteps      | 190400      |
# | train/                  |             |
# |    approx_kl            | 0.034794018 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0.00371     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 9.99        |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | 0.0127      |
# |    reward               | -2.8081357  |
# |    std                  | 12.2        |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 176         |
# |    time_elapsed         | 1660        |
# |    total_timesteps      | 191488      |
# | train/                  |             |
# |    approx_kl            | 0.039875045 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0.00462     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 4.7         |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | 0.00536     |
# |    reward               | 0.88427544  |
# |    std                  | 12.3        |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 177         |
# |    time_elapsed         | 1671        |
# |    total_timesteps      | 192576      |
# | train/                  |             |
# |    approx_kl            | 0.037265025 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 0.00652     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 5.88        |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | 0.00535     |
# |    reward               | -0.19776249 |
# |    std                  | 12.4        |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 178         |
# |    time_elapsed         | 1679        |
# |    total_timesteps      | 193664      |
# | train/                  |             |
# |    approx_kl            | 0.039343376 |
# |    clip_fraction        | 0.437       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.00505     |
# |    loss                 | 4.66        |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | 0.011       |
# |    reward               | 0.68773574  |
# |    std                  | 12.4        |
# |    value_loss           | 11.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 179        |
# |    time_elapsed         | 1689       |
# |    total_timesteps      | 194752     |
# | train/                  |            |
# |    approx_kl            | 0.03632295 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -113       |
# |    explained_variance   | 0.00819    |
# |    learning_rate        | 0.00505    |
# |    loss                 | 7.97       |
# |    n_updates            | 1780       |
# |    policy_gradient_loss | 0.00464    |
# |    reward               | -1.5703347 |
# |    std                  | 12.3       |
# |    value_loss           | 16.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 180        |
# |    time_elapsed         | 1698       |
# |    total_timesteps      | 195840     |
# | train/                  |            |
# |    approx_kl            | 0.03211659 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -113       |
# |    explained_variance   | 0.00176    |
# |    learning_rate        | 0.00505    |
# |    loss                 | 7.45       |
# |    n_updates            | 1790       |
# |    policy_gradient_loss | 0.00172    |
# |    reward               | -1.9832001 |
# |    std                  | 12.4       |
# |    value_loss           | 17.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 181         |
# |    time_elapsed         | 1707        |
# |    total_timesteps      | 196928      |
# | train/                  |             |
# |    approx_kl            | 0.035053544 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 0.00409     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 6.19        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.00364     |
# |    reward               | 1.6119977   |
# |    std                  | 12.5        |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 182         |
# |    time_elapsed         | 1718        |
# |    total_timesteps      | 198016      |
# | train/                  |             |
# |    approx_kl            | 0.044175606 |
# |    clip_fraction        | 0.483       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 0.00428     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 6.46        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.00802     |
# |    reward               | 1.6158457   |
# |    std                  | 12.4        |
# |    value_loss           | 15.9        |
# -----------------------------------------
# day: 1258, episode: 240
# begin_total_asset: 1000000.00
# end_total_asset: 1986444.59
# total_reward: 986444.59
# total_cost: 49540.79
# total_trades: 22305
# Sharpe: 0.854
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 183         |
# |    time_elapsed         | 1726        |
# |    total_timesteps      | 199104      |
# | train/                  |             |
# |    approx_kl            | 0.057376727 |
# |    clip_fraction        | 0.475       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 0.00705     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 6.67        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00605     |
# |    reward               | -1.050198   |
# |    std                  | 12.3        |
# |    value_loss           | 14          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 184         |
# |    time_elapsed         | 1736        |
# |    total_timesteps      | 200192      |
# | train/                  |             |
# |    approx_kl            | 0.040470704 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 0.00587     |
# |    learning_rate        | 0.00505     |
# |    loss                 | 5.68        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00603     |
# |    reward               | 0.12978253  |
# |    std                  | 12.4        |
# |    value_loss           | 17.6        |
# -----------------------------------------

# %%
# ### Agent 4: TD3
agent = DRLAgent(env = env_train)
TD3_PARAMS = {
    "buffer_size": 550000,
    "learning_rate": 0.00505,
    "batch_size": 160,
}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)



trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None



trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
# Out:
# {'buffer_size': 550000, 'learning_rate': 0.00505, 'batch_size': 160}
# Using cpu device
# Logging to results/td3
# day: 1258, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 2229558.43
# total_reward: 1229558.43
# total_cost: 1297.37
# total_trades: 11364
# Sharpe: 1.373
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 24         |
# |    time_elapsed    | 203        |
# |    total_timesteps | 5036       |
# | train/             |            |
# |    actor_loss      | 79.3       |
# |    critic_loss     | 150        |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 3777       |
# |    reward          | -1.1608844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 21         |
# |    time_elapsed    | 465        |
# |    total_timesteps | 10072      |
# | train/             |            |
# |    actor_loss      | 50.7       |
# |    critic_loss     | 245        |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 8813       |
# |    reward          | -1.1608844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 20         |
# |    time_elapsed    | 731        |
# |    total_timesteps | 15108      |
# | train/             |            |
# |    actor_loss      | 39         |
# |    critic_loss     | 507        |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 13849      |
# |    reward          | -1.1608844 |
# -----------------------------------
# day: 1258, episode: 270
# begin_total_asset: 1000000.00
# end_total_asset: 2229558.43
# total_reward: 1229558.43
# total_cost: 1297.37
# total_trades: 11364
# Sharpe: 1.373
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 20         |
# |    time_elapsed    | 999        |
# |    total_timesteps | 20144      |
# | train/             |            |
# |    actor_loss      | 41.8       |
# |    critic_loss     | 32         |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 18885      |
# |    reward          | -1.1608844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 19         |
# |    time_elapsed    | 1267       |
# |    total_timesteps | 25180      |
# | train/             |            |
# |    actor_loss      | 38.5       |
# |    critic_loss     | 36.9       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 23921      |
# |    reward          | -1.1608844 |
# -----------------------------------
# day: 1258, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 2229558.43
# total_reward: 1229558.43
# total_cost: 1297.37
# total_trades: 11364
# Sharpe: 1.373
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 24         |
# |    fps             | 19         |
# |    time_elapsed    | 1536       |
# |    total_timesteps | 30216      |
# | train/             |            |
# |    actor_loss      | 35.3       |
# |    critic_loss     | 19.9       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 28957      |
# |    reward          | -1.1608844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 28         |
# |    fps             | 19         |
# |    time_elapsed    | 1807       |
# |    total_timesteps | 35252      |
# | train/             |            |
# |    actor_loss      | 31.9       |
# |    critic_loss     | 10.3       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 33993      |
# |    reward          | -1.1608844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 32         |
# |    fps             | 19         |
# |    time_elapsed    | 2077       |
# |    total_timesteps | 40288      |
# | train/             |            |
# |    actor_loss      | 33.7       |
# |    critic_loss     | 8.5        |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 39029      |
# |    reward          | -1.1608844 |
# -----------------------------------
# day: 1258, episode: 290
# begin_total_asset: 1000000.00
# end_total_asset: 2229558.43
# total_reward: 1229558.43
# total_cost: 1297.37
# total_trades: 11364
# Sharpe: 1.373
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 36         |
# |    fps             | 19         |
# |    time_elapsed    | 2346       |
# |    total_timesteps | 45324      |
# | train/             |            |
# |    actor_loss      | 29.5       |
# |    critic_loss     | 6.42       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 44065      |
# |    reward          | -1.1608844 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 40         |
# |    fps             | 19         |
# |    time_elapsed    | 2614       |
# |    total_timesteps | 50360      |
# | train/             |            |
# |    actor_loss      | 25.6       |
# |    critic_loss     | 5.48       |
# |    learning_rate   | 0.00505    |
# |    n_updates       | 49101      |
# |    reward          | -1.1608844 |
# -----------------------------------

# %%
# ### Agent 5: SAC

agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 200,
    "buffer_size": 500000,
    "learning_rate": 0.001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)

trained_sac = agent.train_model(model=model_sac,
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None

trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None
# Out:
# {'batch_size': 200, 'buffer_size': 500000, 'learning_rate': 0.001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 17        |
# |    time_elapsed    | 288       |
# |    total_timesteps | 5036      |
# | train/             |           |
# |    actor_loss      | 57.4      |
# |    critic_loss     | 844       |
# |    ent_coef        | 0.022     |
# |    ent_coef_loss   | -37.8     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4935      |
# |    reward          | -0.725399 |
# ----------------------------------
# day: 1258, episode: 360
# begin_total_asset: 1000000.00
# end_total_asset: 2330608.16
# total_reward: 1330608.16
# total_cost: 1199.56
# total_trades: 20225
# Sharpe: 1.437
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 17          |
# |    time_elapsed    | 585         |
# |    total_timesteps | 10072       |
# | train/             |             |
# |    actor_loss      | 14.4        |
# |    critic_loss     | 50.7        |
# |    ent_coef        | 0.00674     |
# |    ent_coef_loss   | -30.8       |
# |    learning_rate   | 0.001       |
# |    n_updates       | 9971        |
# |    reward          | -0.87708133 |
# ------------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 17         |
# |    time_elapsed    | 886        |
# |    total_timesteps | 15108      |
# | train/             |            |
# |    actor_loss      | 15.9       |
# |    critic_loss     | 15.3       |
# |    ent_coef        | 0.00254    |
# |    ent_coef_loss   | -0.27      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 15007      |
# |    reward          | -0.7410638 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 17         |
# |    time_elapsed    | 1179       |
# |    total_timesteps | 20144      |
# | train/             |            |
# |    actor_loss      | 7.75       |
# |    critic_loss     | 1.36       |
# |    ent_coef        | 0.00124    |
# |    ent_coef_loss   | -20        |
# |    learning_rate   | 0.001      |
# |    n_updates       | 20043      |
# |    reward          | -0.7319773 |
# -----------------------------------
# day: 1258, episode: 370
# begin_total_asset: 1000000.00
# end_total_asset: 2067430.52
# total_reward: 1067430.52
# total_cost: 1900.27
# total_trades: 21450
# Sharpe: 1.206
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 17         |
# |    time_elapsed    | 1476       |
# |    total_timesteps | 25180      |
# | train/             |            |
# |    actor_loss      | 6.13       |
# |    critic_loss     | 0.83       |
# |    ent_coef        | 0.00113    |
# |    ent_coef_loss   | 25.3       |
# |    learning_rate   | 0.001      |
# |    n_updates       | 25079      |
# |    reward          | -0.8799549 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 24         |
# |    fps             | 17         |
# |    time_elapsed    | 1775       |
# |    total_timesteps | 30216      |
# | train/             |            |
# |    actor_loss      | 3.05       |
# |    critic_loss     | 0.791      |
# |    ent_coef        | 0.0012     |
# |    ent_coef_loss   | 15         |
# |    learning_rate   | 0.001      |
# |    n_updates       | 30115      |
# |    reward          | -0.8930882 |
# -----------------------------------
# day: 1258, episode: 380
# begin_total_asset: 1000000.00
# end_total_asset: 1999445.69
# total_reward: 999445.69
# total_cost: 1680.91
# total_trades: 22594
# Sharpe: 1.107
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 16        |
# |    time_elapsed    | 2073      |
# |    total_timesteps | 35252     |
# | train/             |           |
# |    actor_loss      | 2.76      |
# |    critic_loss     | 0.564     |
# |    ent_coef        | 0.00112   |
# |    ent_coef_loss   | 1.33      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35151     |
# |    reward          | -0.902691 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 32         |
# |    fps             | 17         |
# |    time_elapsed    | 2368       |
# |    total_timesteps | 40288      |
# | train/             |            |
# |    actor_loss      | 4.11       |
# |    critic_loss     | 0.387      |
# |    ent_coef        | 0.00107    |
# |    ent_coef_loss   | -21.9      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 40187      |
# |    reward          | -0.9312197 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 36         |
# |    fps             | 16         |
# |    time_elapsed    | 2670       |
# |    total_timesteps | 45324      |
# | train/             |            |
# |    actor_loss      | 4.54       |
# |    critic_loss     | 0.278      |
# |    ent_coef        | 0.000946   |
# |    ent_coef_loss   | -18.5      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 45223      |
# |    reward          | -0.8205253 |
# -----------------------------------
# day: 1258, episode: 390
# begin_total_asset: 1000000.00
# end_total_asset: 1866337.86
# total_reward: 866337.86
# total_cost: 2577.43
# total_trades: 22547
# Sharpe: 1.063
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 40         |
# |    fps             | 16         |
# |    time_elapsed    | 2969       |
# |    total_timesteps | 50360      |
# | train/             |            |
# |    actor_loss      | 4.28       |
# |    critic_loss     | 0.211      |
# |    ent_coef        | 0.00092    |
# |    ent_coef_loss   | -36        |
# |    learning_rate   | 0.001      |
# |    n_updates       | 50259      |
# |    reward          | -0.8447214 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 44         |
# |    fps             | 16         |
# |    time_elapsed    | 3278       |
# |    total_timesteps | 55396      |
# | train/             |            |
# |    actor_loss      | 6.17       |
# |    critic_loss     | 0.214      |
# |    ent_coef        | 0.000799   |
# |    ent_coef_loss   | -8.87      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 55295      |
# |    reward          | -0.7594581 |
# -----------------------------------
# day: 1258, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 1924168.16
# total_reward: 924168.16
# total_cost: 2417.78
# total_trades: 22037
# Sharpe: 1.104
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 48         |
# |    fps             | 16         |
# |    time_elapsed    | 3588       |
# |    total_timesteps | 60432      |
# | train/             |            |
# |    actor_loss      | 6.56       |
# |    critic_loss     | 0.224      |
# |    ent_coef        | 0.000788   |
# |    ent_coef_loss   | -16.7      |
# |    learning_rate   | 0.001      |
# |    n_updates       | 60331      |
# |    reward          | -0.7557985 |
# -----------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 52          |
# |    fps             | 16          |
# |    time_elapsed    | 3906        |
# |    total_timesteps | 65468       |
# | train/             |             |
# |    actor_loss      | 5.61        |
# |    critic_loss     | 0.166       |
# |    ent_coef        | 0.000719    |
# |    ent_coef_loss   | 24.4        |
# |    learning_rate   | 0.001       |
# |    n_updates       | 65367       |
# |    reward          | -0.77838093 |
# ------------------------------------

# %%
# # Part 2. Backtesting
train = pd.read_csv('train_data.csv')
trade = pd.read_csv('trade_data.csv')
train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %%
# Load the agents
trained_a2c = A2C.load("trained_models/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load("trained_models/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load("trained_models/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load("trained_models/agent_td3") if if_using_td3 else None
trained_sac = SAC.load("trained_models/agent_sac") if if_using_sac else None

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c,
    environment = e_trade_gym) if if_using_a2c else (None, None)

df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg,
    environment = e_trade_gym) if if_using_ddpg else (None, None)

df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo,
    environment = e_trade_gym) if if_using_ppo else (None, None)

df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3,
    environment = e_trade_gym) if if_using_td3 else (None, None)

df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac,
    environment = e_trade_gym) if if_using_sac else (None, None)
# Out:
# hit end!
# hit end!
# hit end!
# hit end!
# hit end!

# %%
#Mean Variance Optimization
def process_df_for_mvo(df):
  df = df.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
  fst = df
  fst = fst.iloc[0:stock_dimension, :]
  tic = fst['tic'].tolist()

  mvo = pd.DataFrame()

  for k in range(len(tic)):
    mvo[tic[k]] = 0

  for i in range(df.shape[0]//stock_dimension):
    n = df
    n = n.iloc[i * stock_dimension:(i+1) * stock_dimension, :]
    date = n['date'][i*stock_dimension]
    mvo.loc[date] = n['close'].tolist()

  return mvo
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Helper functions for mean returns and variance-covariance matrix

def StockReturnsComputing(StockPrice, Rows, Columns):
  import numpy as np
  StockReturn = np.zeros([Rows-1, Columns])
  for j in range(Columns):        # j: Assets
    for i in range(Rows-1):     # i: Daily Prices
      StockReturn[i,j]=((StockPrice[i+1, j]-StockPrice[i,j])/StockPrice[i,j])* 100

  return StockReturn

# %%
# ### Calculate the weights for mean-variance
StockData = process_df_for_mvo(train)
TradeData = process_df_for_mvo(trade)

TradeData.to_numpy()
# Out:
# array([[ 40.72286987, 147.57382202,  90.79888916, ...,  39.69017792,
#          58.36280441,  88.95238495],
#        [ 40.71578217, 150.35855103,  91.35870361, ...,  38.87458038,
#          58.79888153,  89.72832489],
#        [ 40.9048996 , 149.72489929,  92.87826538, ...,  39.00063324,
#          55.75421524,  89.80953217],
#        ...,
#        [129.30723572, 254.56677246, 144.25646973, ...,  36.5643959 ,
#          35.73909378, 142.17553711],
#        [125.33940887, 252.66278076, 141.91114807, ...,  36.15450287,
#          35.05808258, 139.68417358],
#        [128.88957214, 254.34446716, 145.17289734, ...,  36.5737114 ,
#          34.95546722, 140.53440857]])

# %%
#compute asset returns
arStockPrices = np.asarray(StockData)
[Rows, Cols]=arStockPrices.shape
arReturns = StockReturnsComputing(arStockPrices, Rows, Cols)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis = 0)
covReturns = np.cov(arReturns, rowvar=False)

# %%
#set precision for printing results
np.set_printoptions(precision=3, suppress = True)

# %%
#display mean returns and variance-covariance matrix of returns
print('Mean returns of assets in k-portfolio 1\n', meanReturns)
print('Variance-Covariance matrix of returns\n', covReturns)
# Out:
# Mean returns of assets in k-portfolio 1
#  [ 0.08   0.074  0.055  0.126  0.064  0.087  0.071  0.033  0.071  0.067
#   0.101  0.083 -0.001  0.083  0.069  0.088  0.032  0.068  0.087  0.044
#   0.11   0.084  0.039  0.063  0.125  0.097  0.037  0.071  0.044]
# Variance-Covariance matrix of returns
#  [[2.257 0.596 0.399 0.528 0.647 0.71  0.593 0.436 0.443 0.661 0.434 0.545
#   0.44  0.657 0.296 0.584 0.244 0.336 0.44  0.325 0.73  0.454 0.29  0.35
#   0.468 0.558 0.258 0.518 0.288]
#  [0.596 2.411 0.702 0.672 0.612 0.985 0.584 0.547 0.673 0.87  0.652 0.731
#   0.493 0.691 0.695 0.841 0.34  0.422 0.567 0.865 0.624 0.651 0.46  0.506
#   0.808 0.812 0.415 0.849 0.407]
#  [0.399 0.702 1.493 0.601 0.644 0.71  0.48  0.48  0.536 0.89  0.503 0.606
#   0.452 0.572 0.398 0.839 0.291 0.286 0.474 0.477 0.539 0.563 0.295 0.42
#   0.511 0.709 0.328 0.54  0.288]
#  [0.528 0.672 0.601 1.732 0.732 0.706 0.537 0.572 0.619 0.829 0.496 0.743
#   0.533 0.6   0.427 0.768 0.35  0.372 0.58  0.47  0.539 0.565 0.344 0.466
#   0.542 0.64  0.388 0.577 0.339]
#  [0.647 0.612 0.644 0.732 1.983 0.707 0.646 0.906 0.519 0.969 0.478 0.764
#   0.594 0.718 0.359 0.873 0.251 0.371 0.604 0.435 0.681 0.444 0.289 0.459
#   0.446 0.563 0.379 0.464 0.268]
#  [0.71  0.985 0.71  0.706 0.707 3.582 0.9   0.583 0.767 0.925 0.705 0.765
#   0.59  0.785 0.481 0.868 0.361 0.541 0.639 0.554 0.954 0.851 0.36  0.502
#   0.548 1.019 0.335 0.816 0.307]
#  [0.593 0.584 0.48  0.537 0.646 0.9   1.71  0.576 0.567 0.701 0.469 0.608
#   0.6   0.763 0.411 0.704 0.333 0.363 0.526 0.481 0.745 0.481 0.354 0.418
#   0.46  0.608 0.347 0.485 0.373]
#  [0.436 0.547 0.48  0.572 0.906 0.583 0.576 1.59  0.492 0.782 0.42  0.604
#   0.551 0.59  0.408 0.78  0.354 0.335 0.505 0.496 0.551 0.375 0.393 0.475
#   0.45  0.53  0.412 0.452 0.253]
#  [0.443 0.673 0.536 0.619 0.519 0.767 0.567 0.492 1.319 0.716 0.535 0.584
#   0.459 0.558 0.376 0.677 0.348 0.323 0.46  0.409 0.53  0.608 0.355 0.473
#   0.478 0.599 0.386 0.544 0.326]
#  [0.661 0.87  0.89  0.829 0.969 0.925 0.701 0.782 0.716 1.871 0.624 0.753
#   0.7   0.758 0.455 1.416 0.298 0.397 0.622 0.629 0.745 0.637 0.338 0.65
#   0.693 0.829 0.39  0.69  0.301]
#  [0.434 0.652 0.503 0.496 0.478 0.705 0.469 0.42  0.535 0.624 1.192 0.573
#   0.421 0.494 0.368 0.601 0.298 0.378 0.463 0.395 0.529 0.635 0.305 0.434
#   0.472 0.564 0.35  0.538 0.411]
#  [0.545 0.731 0.606 0.743 0.764 0.765 0.608 0.604 0.584 0.753 0.573 1.063
#   0.511 0.604 0.454 0.754 0.358 0.377 0.631 0.48  0.652 0.583 0.362 0.508
#   0.532 0.686 0.391 0.589 0.363]
#  [0.44  0.493 0.452 0.533 0.594 0.59  0.6   0.551 0.459 0.7   0.421 0.511
#   1.367 0.592 0.367 0.629 0.296 0.333 0.447 0.42  0.589 0.386 0.325 0.425
#   0.409 0.525 0.367 0.386 0.294]
#  [0.657 0.691 0.572 0.6   0.718 0.785 0.763 0.59  0.558 0.758 0.494 0.604
#   0.592 1.827 0.397 0.703 0.349 0.371 0.559 0.486 0.942 0.437 0.371 0.432
#   0.445 0.615 0.4   0.485 0.303]
#  [0.296 0.695 0.398 0.427 0.359 0.481 0.411 0.408 0.376 0.455 0.368 0.454
#   0.367 0.397 0.754 0.459 0.304 0.332 0.437 0.502 0.416 0.376 0.355 0.374
#   0.437 0.476 0.344 0.468 0.306]
#  [0.584 0.841 0.839 0.768 0.873 0.868 0.704 0.78  0.677 1.416 0.601 0.754
#   0.629 0.703 0.459 1.622 0.316 0.409 0.601 0.604 0.724 0.618 0.355 0.662
#   0.67  0.756 0.419 0.626 0.343]
#  [0.244 0.34  0.291 0.35  0.251 0.361 0.333 0.354 0.348 0.298 0.298 0.358
#   0.296 0.349 0.304 0.316 0.753 0.328 0.313 0.3   0.363 0.325 0.409 0.361
#   0.269 0.361 0.323 0.323 0.294]
#  [0.336 0.422 0.286 0.372 0.371 0.541 0.363 0.335 0.323 0.397 0.378 0.377
#   0.333 0.371 0.332 0.409 0.328 0.85  0.343 0.329 0.468 0.397 0.297 0.345
#   0.321 0.418 0.271 0.356 0.276]
#  [0.44  0.567 0.474 0.58  0.604 0.639 0.526 0.505 0.46  0.622 0.463 0.631
#   0.447 0.559 0.437 0.601 0.313 0.343 0.9   0.422 0.523 0.444 0.347 0.462
#   0.437 0.535 0.369 0.462 0.287]
#  [0.325 0.865 0.477 0.47  0.435 0.554 0.481 0.496 0.409 0.629 0.395 0.48
#   0.42  0.486 0.502 0.604 0.3   0.329 0.422 1.425 0.445 0.412 0.352 0.364
#   0.465 0.496 0.403 0.553 0.343]
#  [0.73  0.624 0.539 0.539 0.681 0.954 0.745 0.551 0.53  0.745 0.529 0.652
#   0.589 0.942 0.416 0.724 0.363 0.468 0.523 0.445 1.983 0.536 0.411 0.45
#   0.532 0.747 0.42  0.612 0.338]
#  [0.454 0.651 0.563 0.565 0.444 0.851 0.481 0.375 0.608 0.637 0.635 0.583
#   0.386 0.437 0.376 0.618 0.325 0.397 0.444 0.412 0.536 1.872 0.33  0.406
#   0.464 0.657 0.322 0.57  0.38 ]
#  [0.29  0.46  0.295 0.344 0.289 0.36  0.354 0.393 0.355 0.338 0.305 0.362
#   0.325 0.371 0.355 0.355 0.409 0.297 0.347 0.352 0.411 0.33  0.767 0.367
#   0.304 0.393 0.334 0.393 0.346]
#  [0.35  0.506 0.42  0.466 0.459 0.502 0.418 0.475 0.473 0.65  0.434 0.508
#   0.425 0.432 0.374 0.662 0.361 0.345 0.462 0.364 0.45  0.406 0.367 0.898
#   0.448 0.489 0.354 0.447 0.288]
#  [0.468 0.808 0.511 0.542 0.446 0.548 0.46  0.45  0.478 0.693 0.472 0.532
#   0.409 0.445 0.437 0.67  0.269 0.321 0.437 0.465 0.532 0.464 0.304 0.448
#   1.578 0.525 0.23  0.571 0.353]
#  [0.558 0.812 0.709 0.64  0.563 1.019 0.608 0.53  0.599 0.829 0.564 0.686
#   0.525 0.615 0.476 0.756 0.361 0.418 0.535 0.496 0.747 0.657 0.393 0.489
#   0.525 1.604 0.344 0.591 0.343]
#  [0.258 0.415 0.328 0.388 0.379 0.335 0.347 0.412 0.386 0.39  0.35  0.391
#   0.367 0.4   0.344 0.419 0.323 0.271 0.369 0.403 0.42  0.322 0.334 0.354
#   0.23  0.344 1.034 0.405 0.324]
#  [0.518 0.849 0.54  0.577 0.464 0.816 0.485 0.452 0.544 0.69  0.538 0.589
#   0.386 0.485 0.468 0.626 0.323 0.356 0.462 0.553 0.612 0.57  0.393 0.447
#   0.571 0.591 0.405 2.251 0.44 ]
#  [0.288 0.407 0.288 0.339 0.268 0.307 0.373 0.253 0.326 0.301 0.411 0.363
#   0.294 0.303 0.306 0.343 0.294 0.276 0.287 0.343 0.338 0.38  0.346 0.288
#   0.353 0.343 0.324 0.44  1.16 ]]

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covReturns, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe()
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(29)])
mvo_weights
# Out:
# array([     0.,      0.,      0., 250320.,      0.,      0.,      0.,
#             0.,      0.,      0., 216500.,      0.,      0.,      0.,
#             0.,      0.,      0.,  20520.,  74310.,      0., 121570.,
#             0.,      0.,      0., 304020.,  12770.,      0.,      0.,
#             0.])

# %%
LastPrice = np.array([1/p for p in StockData.tail(1).to_numpy()[0]])
Initial_Portfolio = np.multiply(mvo_weights, LastPrice)
Initial_Portfolio
# Out:
# array([   0.   ,    0.   ,    0.   ,  890.669,    0.   ,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   , 1312.401,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   ,    0.   ,  136.41 ,
#         396.309,    0.   , 1522.55 ,    0.   ,    0.   ,    0.   ,
#        1500.939,  116.655,    0.   ,    0.   ,    0.   ])

# %%
Portfolio_Assets = TradeData @ Initial_Portfolio
MVO_result = pd.DataFrame(Portfolio_Assets, columns=["Mean Var"])

# %%
df_dji = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['dji']).fetch_data()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (877, 8)

# %%
df_dji = df_dji[['date','close']]
fst_day = df_dji['close'][0]
dji = pd.merge(df_dji['date'], df_dji['close'].div(fst_day).mul(1000000),
               how='outer', left_index=True, right_index=True).set_index('date')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None
result = pd.DataFrame()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True)
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True)
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True)
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True)
result = pd.merge(result, MVO_result, how='outer', left_index=True, right_index=True)
result = pd.merge(result, dji, how='outer', left_index=True, right_index=True).fillna(method='bfill')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-53-df10d0a9d66d>:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'account_value_x'} in the result is deprecated and will raise a MergeError in a future version.
#   if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True)

# %%
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('Mean Var')
col_name.append('djia')
result.columns = col_name
result
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      A2C          DDPG           PPO           TD3  \
# date
# 2018-01-02  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 2018-01-03  1.000424e+06  1.000337e+06  1.000514e+06  1.000378e+06
# 2018-01-04  1.001069e+06  1.003113e+06  1.001499e+06  1.001208e+06
# 2018-01-05  1.004973e+06  1.010404e+06  1.006754e+06  1.002930e+06
# 2018-01-08  1.005854e+06  1.009258e+06  1.007320e+06  1.002911e+06
# ...                  ...           ...           ...           ...
# 2022-12-22  1.368329e+06  1.642881e+06  1.406224e+06  1.272972e+06
# 2022-12-23  1.377728e+06  1.653866e+06  1.410874e+06  1.273247e+06
# 2022-12-27  1.381342e+06  1.656558e+06  1.410180e+06  1.274610e+06
# 2022-12-28  1.366772e+06  1.640987e+06  1.398969e+06  1.259905e+06
# 2022-12-29  1.380668e+06  1.656156e+06  1.415959e+06  1.275002e+06
#
#                      SAC      Mean Var          djia
# date
# 2018-01-02  1.000000e+06  1.001754e+06  1.000000e+06
# 2018-01-03  1.000089e+06  1.007494e+06  1.003976e+06
# 2018-01-04  1.001234e+06  1.011830e+06  1.010115e+06
# 2018-01-05  1.003341e+06  1.032811e+06  1.019010e+06
# 2018-01-08  1.004944e+06  1.027844e+06  1.018490e+06
# ...                  ...           ...           ...
# 2022-12-22  1.428426e+06  1.820383e+06           NaN
# 2022-12-23  1.439109e+06  1.831325e+06           NaN
# 2022-12-27  1.446389e+06  1.831004e+06           NaN
# 2022-12-28  1.428136e+06  1.815162e+06           NaN
# 2022-12-29  1.448225e+06  1.834868e+06           NaN
#
# [1258 rows x 7 columns]

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: xlabel='date'>
